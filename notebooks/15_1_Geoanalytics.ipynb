# %%
pip install pandas numpy requests  plotly folium keplergl tqdm
# Out:
# Requirement already satisfied: pandas in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (2.4.4)
# Requirement already satisfied: requests in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (2.34.2)
# Requirement already satisfied: plotly in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (6.8.0)
# Requirement already satisfied: folium in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (0.20.0)
# Collecting keplergl
#   Using cached keplergl-0.3.7.tar.gz (18.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for keplergl did not run successfully.
#   │ exit code: 1
#   ╰─> [56 lines of output]
#       Collecting geopandas~=0.14.3
#         Using cached geopandas-0.14.4-py3-none-any.whl.metadata (1.5 kB)
#       Collecting ipywidgets~=8.1.5
#         Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
#       Collecting notebook~=6.0.1
#         Using cached notebook-6.0.3-py3-none-any.whl.metadata (2.0 kB)
#       Collecting jupyter_packaging~=0.12.3
#         Using cached jupyter_packaging-0.12.3-py3-none-any.whl.metadata (7.7 kB)
#       Collecting jupyter-contrib-nbextensions~=0.7.0
#         Using cached jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'done'
#       Collecting jupyterlab~=4.1.6
#         Using cached jupyterlab-4.1.8-py3-none-any.whl.metadata (16 kB)
#       Collecting pyarrow~=16.0.0
#         Using cached pyarrow-16.0.0.tar.gz (1.1 MB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Getting requirements to build wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [23 lines of output]
#             Traceback (most recent call last):
#               File "C:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#                 main()
#                 ~~~~^^
#               File "C:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#                 json_out["return_val"] = hook(**hook_input["kwargs"])
#                                          ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#                 return hook(config_settings)
#               File "C:\Users\ArmTa\AppData\Local\Temp\pip-build-env-zob1ucot\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#                 return self._get_build_requires(config_settings, requirements=[])
#                        ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ArmTa\AppData\Local\Temp\pip-build-env-zob1ucot\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#                 self.run_setup()
#                 ~~~~~~~~~~~~~~^^
#               File "C:\Users\ArmTa\AppData\Local\Temp\pip-build-env-zob1ucot\overlay\Lib\site-packages\setuptools\build_meta.py", line 520, in run_setup
#                 super().run_setup(setup_script=setup_script)
#                 ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ArmTa\AppData\Local\Temp\pip-build-env-zob1ucot\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#                 exec(code, locals())
#                 ~~~~^^^^^^^^^^^^^^^^
#               File "<string>", line 34, in <module>
#             ModuleNotFoundError: No module named 'pkg_resources'
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       ERROR: Failed to build 'pyarrow' when getting requirements to build wheel
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'keplergl' when installing build dependencies for keplergl

# %%
conda install pandas numpy requests  plotly folium keplergl tqdm
# Out:
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - keplergl
#
# Current channels:
#
#   - defaults
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import pandas as pd

# %%
import os

# %%
import zipfile

# %%
# %pip install requests
# the requests library isn't installed in the Python environment your Jupyter kernel is using. It's a third-party package, so it doesn't come bundled with Python by default.
# Out:
# Requirement already satisfied: requests in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
import numpy as np

# %%
import pandas as pd

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (6.8.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from plotly) (2.22.1)
# Requirement already satisfied: packaging in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from plotly) (26.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
# %pip install folium tqdm
# Out:
# Requirement already satisfied: folium in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (0.20.0)
# Requirement already satisfied: tqdm in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (4.68.2)
# Requirement already satisfied: branca>=0.6.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (2.4.4)
# Requirement already satisfied: requests in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (2.34.2)
# Requirement already satisfied: xyzservices in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (2026.3.0)
# Requirement already satisfied: colorama in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests->folium) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests->folium) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests->folium) (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
# %pip install requests plotly folium tqdm
# Out:
# Requirement already satisfied: requests in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (2.34.2)
# Requirement already satisfied: plotly in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (6.8.0)
# Requirement already satisfied: folium in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (0.20.0)
# Requirement already satisfied: tqdm in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (4.68.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (2026.5.20)
# Requirement already satisfied: narwhals>=1.15.1 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from plotly) (2.22.1)
# Requirement already satisfied: packaging in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from plotly) (26.0)
# Requirement already satisfied: branca>=0.6.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (2.4.4)
# Requirement already satisfied: xyzservices in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (2026.3.0)
# Requirement already satisfied: colorama in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tqdm import tqdm

# %%
from pathlib import Path

# %%
trip_demo = pd.DataFrame({
    "ride_id": list(range(1, 21)),

    "start_station": [
        "Station A", "Station A", "Station A", "Station A", "Station A",
        "Station B", "Station B", "Station B", "Station B",
        "Station C", "Station C", "Station C",
        "Station D", "Station D", "Station D",
        "Station E", "Station E",
        "Station A", "Station B", "Station C"
    ],

    "end_station": [
        "Station B", "Station B", "Station B", "Station C", "Station C",
        "Station A", "Station A", "Station C", "Station D",
        "Station A", "Station B", "Station E",
        "Station A", "Station C", "Station E",
        "Station A", "Station D",
        "Station E", "Station E", "Station D"
    ],

    "started_at": pd.to_datetime([
        "2025-01-01 08:00", "2025-01-01 08:15", "2025-01-01 08:30",
        "2025-01-01 09:00", "2025-01-01 09:20",
        "2025-01-01 10:00", "2025-01-01 10:15", "2025-01-01 10:40",
        "2025-01-01 11:00",
        "2025-01-01 11:30", "2025-01-01 12:00", "2025-01-01 12:20",
        "2025-01-01 13:00", "2025-01-01 13:30", "2025-01-01 14:00",
        "2025-01-01 14:30", "2025-01-01 15:00",
        "2025-01-01 15:30", "2025-01-01 16:00", "2025-01-01 16:30"
    ]),

    "ended_at": pd.to_datetime([
        "2025-01-01 08:10", "2025-01-01 08:28", "2025-01-01 08:42",
        "2025-01-01 09:18", "2025-01-01 09:35",
        "2025-01-01 10:12", "2025-01-01 10:30", "2025-01-01 10:55",
        "2025-01-01 11:18",
        "2025-01-01 11:48", "2025-01-01 12:14", "2025-01-01 12:45",
        "2025-01-01 13:20", "2025-01-01 13:48", "2025-01-01 14:20",
        "2025-01-01 14:55", "2025-01-01 15:22",
        "2025-01-01 15:58", "2025-01-01 16:25", "2025-01-01 16:50"
    ]),

    "member_casual": [
        "member", "member", "casual", "member", "casual",
        "member", "member", "casual", "member",
        "casual", "member", "casual",
        "member", "casual", "member",
        "casual", "member",
        "member", "casual", "member"
    ]
})

trip_demo
# Out:
#     ride_id start_station end_station          started_at            ended_at  \
# 0         1     Station A   Station B 2025-01-01 08:00:00 2025-01-01 08:10:00
# 1         2     Station A   Station B 2025-01-01 08:15:00 2025-01-01 08:28:00
# 2         3     Station A   Station B 2025-01-01 08:30:00 2025-01-01 08:42:00
# 3         4     Station A   Station C 2025-01-01 09:00:00 2025-01-01 09:18:00
# 4         5     Station A   Station C 2025-01-01 09:20:00 2025-01-01 09:35:00
# 5         6     Station B   Station A 2025-01-01 10:00:00 2025-01-01 10:12:00
# 6         7     Station B   Station A 2025-01-01 10:15:00 2025-01-01 10:30:00
# 7         8     Station B   Station C 2025-01-01 10:40:00 2025-01-01 10:55:00
# 8         9     Station B   Station D 2025-01-01 11:00:00 2025-01-01 11:18:00
# 9        10     Station C   Station A 2025-01-01 11:30:00 2025-01-01 11:48:00
# 10       11     Station C   Station B 2025-01-01 12:00:00 2025-01-01 12:14:00
# 11       12     Station C   Station E 2025-01-01 12:20:00 2025-01-01 12:45:00
# 12       13     Station D   Station A 2025-01-01 13:00:00 2025-01-01 13:20:00
# 13       14     Station D   Station C 2025-01-01 13:30:00 2025-01-01 13:48:00
# 14       15     Station D   Station E 2025-01-01 14:00:00 2025-01-01 14:20:00
# 15       16     Station E   Station A 2025-01-01 14:30:00 2025-01-01 14:55:00
# 16       17     Station E   Station D 2025-01-01 15:00:00 2025-01-01 15:22:00
# 17       18     Station A   Station E 2025-01-01 15:30:00 2025-01-01 15:58:00
# 18       19     Station B   Station E 2025-01-01 16:00:00 2025-01-01 16:25:00
# 19       20     Station C   Station D 2025-01-01 16:30:00 2025-01-01 16:50:00
#
#    member_casual
# 0         member
# 1         member
# 2         casual
# 3         member
# 4         casual
# 5         member
# 6         member
# 7         casual
# 8         member
# 9         casual
# 10        member
# 11        casual
# 12        member
# 13        casual
# 14        member
# 15        casual
# 16        member
# 17        member
# 18        casual
# 19        member

# %%
station_coordinates = pd.DataFrame({
    "station": [
        "Station A",
        "Station B",
        "Station C",
        "Station D",
        "Station E"
    ],
    "lat": [
        40.735,
        40.751,
        40.742,
        40.728,
        40.760
    ],
    "lng": [
        -73.991,
        -73.977,
        -73.985,
        -73.970,
        -73.995
    ]
})

station_coordinates
# Out:
#      station     lat     lng
# 0  Station A  40.735 -73.991
# 1  Station B  40.751 -73.977
# 2  Station C  40.742 -73.985
# 3  Station D  40.728 -73.970
# 4  Station E  40.760 -73.995

# %%
trip_demo = (
    trip_demo
    .merge(
        station_coordinates,
        left_on="start_station",
        right_on="station",
        how="left"
    )
    .rename(columns={
        "lat": "start_lat",
        "lng": "start_lng"
    })
    .drop(columns="station")
    .merge(
        station_coordinates,
        left_on="end_station",
        right_on="station",
        how="left"
    )
    .rename(columns={
        "lat": "end_lat",
        "lng": "end_lng"
    })
    .drop(columns="station")
)

trip_demo.head()
# Out:
#    ride_id start_station end_station          started_at            ended_at  \
# 0        1     Station A   Station B 2025-01-01 08:00:00 2025-01-01 08:10:00
# 1        2     Station A   Station B 2025-01-01 08:15:00 2025-01-01 08:28:00
# 2        3     Station A   Station B 2025-01-01 08:30:00 2025-01-01 08:42:00
# 3        4     Station A   Station C 2025-01-01 09:00:00 2025-01-01 09:18:00
# 4        5     Station A   Station C 2025-01-01 09:20:00 2025-01-01 09:35:00
#
#   member_casual  start_lat  start_lng  end_lat  end_lng
# 0        member     40.735    -73.991   40.751  -73.977
# 1        member     40.735    -73.991   40.751  -73.977
# 2        casual     40.735    -73.991   40.751  -73.977
# 3        member     40.735    -73.991   40.742  -73.985
# 4        casual     40.735    -73.991   40.742  -73.985

# %%
map_center = [
    pd.concat([trip_demo["start_lat"], trip_demo["end_lat"]]).mean(),
    pd.concat([trip_demo["start_lng"], trip_demo["end_lng"]]).mean()
]

map_center
# Out:
# [np.float64(40.7427), np.float64(-73.9841)]

# %%
trip_demo["duration_min"] = (
    trip_demo["ended_at"] - trip_demo["started_at"]
).dt.total_seconds() / 60

trip_demo[[
    "ride_id",
    "start_station",
    "end_station",
    "started_at",
    "ended_at",
    "duration_min"
]].head()
# Out:
#    ride_id start_station end_station          started_at            ended_at  \
# 0        1     Station A   Station B 2025-01-01 08:00:00 2025-01-01 08:10:00
# 1        2     Station A   Station B 2025-01-01 08:15:00 2025-01-01 08:28:00
# 2        3     Station A   Station B 2025-01-01 08:30:00 2025-01-01 08:42:00
# 3        4     Station A   Station C 2025-01-01 09:00:00 2025-01-01 09:18:00
# 4        5     Station A   Station C 2025-01-01 09:20:00 2025-01-01 09:35:00
#
#    duration_min
# 0          10.0
# 1          13.0
# 2          12.0
# 3          18.0
# 4          15.0

# %%
trip_demo["date"] = trip_demo["started_at"].dt.date
trip_demo["hour"] = trip_demo["started_at"].dt.hour
trip_demo["day_name"] = trip_demo["started_at"].dt.day_name()
trip_demo["month_name"] = trip_demo["started_at"].dt.month_name()

trip_demo.head()
# Out:
#    ride_id start_station end_station          started_at            ended_at  \
# 0        1     Station A   Station B 2025-01-01 08:00:00 2025-01-01 08:10:00
# 1        2     Station A   Station B 2025-01-01 08:15:00 2025-01-01 08:28:00
# 2        3     Station A   Station B 2025-01-01 08:30:00 2025-01-01 08:42:00
# 3        4     Station A   Station C 2025-01-01 09:00:00 2025-01-01 09:18:00
# 4        5     Station A   Station C 2025-01-01 09:20:00 2025-01-01 09:35:00
#
#   member_casual  start_lat  start_lng  end_lat  end_lng  duration_min  \
# 0        member     40.735    -73.991   40.751  -73.977          10.0
# 1        member     40.735    -73.991   40.751  -73.977          13.0
# 2        casual     40.735    -73.991   40.751  -73.977          12.0
# 3        member     40.735    -73.991   40.742  -73.985          18.0
# 4        casual     40.735    -73.991   40.742  -73.985          15.0
#
#          date  hour   day_name month_name
# 0  2025-01-01     8  Wednesday    January
# 1  2025-01-01     8  Wednesday    January
# 2  2025-01-01     8  Wednesday    January
# 3  2025-01-01     9  Wednesday    January
# 4  2025-01-01     9  Wednesday    January

# %%
m = folium.Map(
    location=map_center,
    zoom_start=13
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d4c251a39abeb206070f52a71a9af45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d4c251a39abeb206070f52a71a9af45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d4c251a39abeb206070f52a71a9af45 = L.map(
#                 &quot;map_6d4c251a39abeb206070f52a71a9af45&quot;,
#                 {
#                     center: [40.7427, -73.9841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a038e3785b7614d710afafe90106747 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a038e3785b7614d710afafe90106747.addTo(map_6d4c251a39abeb206070f52a71a9af45);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for _, row in station_coordinates.iterrows():
    folium.Marker(
        location=[row["lat"], row["lng"]],
        popup=row["station"]
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5ca0c7e9135585a85d562e5bb5935f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5ca0c7e9135585a85d562e5bb5935f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5ca0c7e9135585a85d562e5bb5935f9 = L.map(
#                 &quot;map_c5ca0c7e9135585a85d562e5bb5935f9&quot;,
#                 {
#                     center: [40.7427, -73.9841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b65ef78c8ce171ec884e7dcc9b51705 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b65ef78c8ce171ec884e7dcc9b51705.addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#             tile_layer_2b65ef78c8ce171ec884e7dcc9b51705.addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#             var marker_f8487c429ad9169af14550e6272bbb2c = L.marker(
#                 [40.735, -73.991],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_52ad7a2169dc4fda08509b018a2c4800 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49218ab1d21e7431e33f1291d4573f02 = $(`&lt;div id=&quot;html_49218ab1d21e7431e33f1291d4573f02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station A&lt;/div&gt;`)[0];
#                 popup_52ad7a2169dc4fda08509b018a2c4800.setContent(html_49218ab1d21e7431e33f1291d4573f02);
#
#
#
#         marker_f8487c429ad9169af14550e6272bbb2c.bindPopup(popup_52ad7a2169dc4fda08509b018a2c4800)
#         ;
#
#
#
#
#             var marker_01e3a171d6d8239b414cb05c16343303 = L.marker(
#                 [40.751, -73.977],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_749cb58051035b2c4987eedf57eeeefa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cd12c134e9200fb8f7a34bf1da04eca = $(`&lt;div id=&quot;html_1cd12c134e9200fb8f7a34bf1da04eca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station B&lt;/div&gt;`)[0];
#                 popup_749cb58051035b2c4987eedf57eeeefa.setContent(html_1cd12c134e9200fb8f7a34bf1da04eca);
#
#
#
#         marker_01e3a171d6d8239b414cb05c16343303.bindPopup(popup_749cb58051035b2c4987eedf57eeeefa)
#         ;
#
#
#
#
#             var marker_b417bc4bfa7ee23b42680e0909451923 = L.marker(
#                 [40.742, -73.985],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_9078ece60681ca87a9ff732362140f15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35c8ab23df8951d16081a8860cd69f41 = $(`&lt;div id=&quot;html_35c8ab23df8951d16081a8860cd69f41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station C&lt;/div&gt;`)[0];
#                 popup_9078ece60681ca87a9ff732362140f15.setContent(html_35c8ab23df8951d16081a8860cd69f41);
#
#
#
#         marker_b417bc4bfa7ee23b42680e0909451923.bindPopup(popup_9078ece60681ca87a9ff732362140f15)
#         ;
#
#
#
#
#             var marker_fafa2211be736a068e369e4e815b1d17 = L.marker(
#                 [40.728, -73.97],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_b97f501853eb1e6befad15d0927e27be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ee95b19416b353efbbf00f79c4fa511 = $(`&lt;div id=&quot;html_6ee95b19416b353efbbf00f79c4fa511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station D&lt;/div&gt;`)[0];
#                 popup_b97f501853eb1e6befad15d0927e27be.setContent(html_6ee95b19416b353efbbf00f79c4fa511);
#
#
#
#         marker_fafa2211be736a068e369e4e815b1d17.bindPopup(popup_b97f501853eb1e6befad15d0927e27be)
#         ;
#
#
#
#
#             var marker_ab09bb46663d50df8da609d52cbc0451 = L.marker(
#                 [40.76, -73.995],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_f0a64e5b9fec3b5fc19d49b047175a52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2003b988e6832dcac9cf9d38d62c638c = $(`&lt;div id=&quot;html_2003b988e6832dcac9cf9d38d62c638c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station E&lt;/div&gt;`)[0];
#                 popup_f0a64e5b9fec3b5fc19d49b047175a52.setContent(html_2003b988e

# %%
m = folium.Map(
    location=[40.74, -73.99],
    zoom_start=13
)

start_point = [trip_demo.loc[0, "start_lat"], trip_demo.loc[0, "start_lng"]]
end_point = [trip_demo.loc[0, "end_lat"], trip_demo.loc[0, "end_lng"]]

folium.Marker(start_point, popup="Start").add_to(m)
folium.Marker(end_point, popup="End").add_to(m)

folium.PolyLine(
    locations=[start_point, end_point],
    weight=5,
    opacity=0.8
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd1608ce49b0ee47cd41f6460ce7b0bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd1608ce49b0ee47cd41f6460ce7b0bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd1608ce49b0ee47cd41f6460ce7b0bf = L.map(
#                 &quot;map_cd1608ce49b0ee47cd41f6460ce7b0bf&quot;,
#                 {
#                     center: [40.74, -73.99],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4514b7c9e909117e1b357fbf2aade84 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4514b7c9e909117e1b357fbf2aade84.addTo(map_cd1608ce49b0ee47cd41f6460ce7b0bf);
#
#
#             var marker_5e75b80861f75854f4fc7e6c04dabe4c = L.marker(
#                 [40.735, -73.991],
#                 {
# }
#             ).addTo(map_cd1608ce49b0ee47cd41f6460ce7b0bf);
#
#
#         var popup_06e7bf0042712918da7580491c3b6131 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efafa6c22b24d2d49acd5ff250b05a0e = $(`&lt;div id=&quot;html_efafa6c22b24d2d49acd5ff250b05a0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_06e7bf0042712918da7580491c3b6131.setContent(html_efafa6c22b24d2d49acd5ff250b05a0e);
#
#
#
#         marker_5e75b80861f75854f4fc7e6c04dabe4c.bindPopup(popup_06e7bf0042712918da7580491c3b6131)
#         ;
#
#
#
#
#             var marker_fc015f5ec14814b129ebdf05de99b9b5 = L.marker(
#                 [40.751, -73.977],
#                 {
# }
#             ).addTo(map_cd1608ce49b0ee47cd41f6460ce7b0bf);
#
#
#         var popup_3b89b6bda583719c93c013491414bed3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de1b53a23c77b0734865f84148d367e1 = $(`&lt;div id=&quot;html_de1b53a23c77b0734865f84148d367e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_3b89b6bda583719c93c013491414bed3.setContent(html_de1b53a23c77b0734865f84148d367e1);
#
#
#
#         marker_fc015f5ec14814b129ebdf05de99b9b5.bindPopup(popup_3b89b6bda583719c93c013491414bed3)
#         ;
#
#
#
#
#             var poly_line_a188e4dedb8bdeccca3d51165ac7376e = L.polyline(
#                 [[40.735, -73.991], [40.751, -73.977]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_cd1608ce49b0ee47cd41f6460ce7b0bf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
flow_data = (
    trip_demo
    .groupby(
        ["start_station", "end_station"],
        as_index=False
    )
    .agg(
        number_of_rides=("ride_id", "count"),
        avg_duration_min=("duration_min", "mean"),
        start_lat=("start_lat", "mean"),
        start_lng=("start_lng", "mean"),
        end_lat=("end_lat", "mean"),
        end_lng=("end_lng", "mean")
    )
    .sort_values("number_of_rides", ascending=False)
)

flow_data
# Out:
#    start_station end_station  number_of_rides  avg_duration_min  start_lat  \
# 0      Station A   Station B                3         11.666667     40.735
# 1      Station A   Station C                2         16.500000     40.735
# 3      Station B   Station A                2         13.500000     40.751
# 2      Station A   Station E                1         28.000000     40.735
# 4      Station B   Station C                1         15.000000     40.751
# 5      Station B   Station D                1         18.000000     40.751
# 6      Station B   Station E                1         25.000000     40.751
# 7      Station C   Station A                1         18.000000     40.742
# 8      Station C   Station B                1         14.000000     40.742
# 9      Station C   Station D                1         20.000000     40.742
# 10     Station C   Station E                1         25.000000     40.742
# 11     Station D   Station A                1         20.000000     40.728
# 12     Station D   Station C                1         18.000000     40.728
# 13     Station D   Station E                1         20.000000     40.728
# 14     Station E   Station A                1         25.000000     40.760
# 15     Station E   Station D                1         22.000000     40.760
#
#     start_lng  end_lat  end_lng
# 0     -73.991   40.751  -73.977
# 1     -73.991   40.742  -73.985
# 3     -73.977   40.735  -73.991
# 2     -73.991   40.760  -73.995
# 4     -73.977   40.742  -73.985
# 5     -73.977   40.728  -73.970
# 6     -73.977   40.760  -73.995
# 7     -73.985   40.735  -73.991
# 8     -73.985   40.751  -73.977
# 9     -73.985   40.728  -73.970
# 10    -73.985   40.760  -73.995
# 11    -73.970   40.735  -73.991
# 12    -73.970   40.742  -73.985
# 13    -73.970   40.760  -73.995
# 14    -73.995   40.735  -73.991
# 15    -73.995   40.728  -73.970

# %%
flow_map = folium.Map(
    location=map_center,
    zoom_start=13,
    tiles="CartoDB positron"
)

for _, row in station_coordinates.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lng"]],
        radius=6,
        popup=row["station"],
        tooltip=row["station"],
        fill=True
    ).add_to(flow_map)

max_rides = flow_data["number_of_rides"].max()

for _, row in flow_data.iterrows():

    start_point = [row["start_lat"], row["start_lng"]]
    end_point = [row["end_lat"], row["end_lng"]]

    line_width = 1 + 7 * row["number_of_rides"] / max_rides

    popup_text = (
        f"<b>{row['start_station']} → {row['end_station']}</b><br>"
        f"Number of rides: {row['number_of_rides']}<br>"
        f"Average duration: {row['avg_duration_min']:.1f} minutes"
    )

    folium.PolyLine(
        locations=[start_point, end_point],
        weight=line_width,
        opacity=0.7,
        popup=popup_text,
        tooltip=f"{row['start_station']} → {row['end_station']}"
    ).add_to(flow_map)

flow_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fee868ee1ae8e02dc3456e7613dab36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fee868ee1ae8e02dc3456e7613dab36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fee868ee1ae8e02dc3456e7613dab36 = L.map(
#                 &quot;map_0fee868ee1ae8e02dc3456e7613dab36&quot;,
#                 {
#                     center: [40.7427, -73.9841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3114648d7b6b28668483af168603fc6d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3114648d7b6b28668483af168603fc6d.addTo(map_0fee868ee1ae8e02dc3456e7613dab36);
#
#
#             var circle_marker_ffc36e3940ffb19cabff068fac96d526 = L.circleMarker(
#                 [40.735, -73.991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fee868ee1ae8e02dc3456e7613dab36);
#
#
#         var popup_1add924b2508d04b7ae6f597b0f7faae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94347d6b9b4d3ca543e2b8bdd303a745 = $(`&lt;div id=&quot;html_94347d6b9b4d3ca543e2b8bdd303a745&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station A&lt;/div&gt;`)[0];
#                 popup_1add924b2508d04b7ae6f597b0f7faae.setContent(html_94347d6b9b4d3ca543e2b8bdd303a745);
#
#
#
#         circle_marker_ffc36e3940ffb19cabff068fac96d526.bindPopup(popup_1add924b2508d04b7ae6f597b0f7faae)
#         ;
#
#
#
#
#             circle_marker_ffc36e3940ffb19cabff068fac96d526.bindTooltip(
#                 `&lt;div&gt;
#                      Station A
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e6132b20858d9ffa4cac609599547734 = L.circleMarker(
#                 [40.751, -73.977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fee868ee1ae8e02dc3456e7613dab36);
#
#
#         var popup_7b05ab0c1d79d389ce33793c192ad30a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a343f519e67c40ca6eeb30ef79c30003 = $(`&lt;div id=&quot;html_a343f519e67c40ca6eeb30ef79c30003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station B&lt;/div&gt;`)[0];
#                 popup_7b05ab0c1d79d389ce33793c192ad30a.setContent(html_a343f519e67c40ca6eeb30ef79c30003);
#
#
#
#         circle_marker_e6132b20858d9ffa4cac609599547734.bindPopup(popup_7b05ab0c1d79d389ce33793c192ad30a)
#         ;
#
#
#
#
#             circle_marker_e6132b20858d9ffa4cac609599547734.bindTooltip(
#                 `&lt;div&gt;
#                      Station B
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ef34abc569a53eed2b130b431a1c3660 = L.circleMarker(
#                 [40.742, -73.985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fee868ee1ae8e02dc3456e7613dab36);
#
#
#         var popup_c320926efad8867603a2bc9c5c1e4e83 = L.popup({
#   &quot;maxWidth&quot;: &quot;10

# %%
min_lat = min(trip_demo["start_lat"].min(), trip_demo["end_lat"].min())
max_lat = max(trip_demo["start_lat"].max(), trip_demo["end_lat"].max())

min_lng = min(trip_demo["start_lng"].min(), trip_demo["end_lng"].min())
max_lng = max(trip_demo["start_lng"].max(), trip_demo["end_lng"].max())

bounding_box = pd.DataFrame({
    "metric": ["min_lat", "max_lat", "min_lng", "max_lng"],
    "value": [min_lat, max_lat, min_lng, max_lng]
})

bounding_box
# Out:
#     metric   value
# 0  min_lat  40.728
# 1  max_lat  40.760
# 2  min_lng -73.995
# 3  max_lng -73.970

# %%
bbox_map = folium.Map(
    location=map_center,
    zoom_start=13,
    tiles="CartoDB positron"
)

for _, row in station_coordinates.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lng"]],
        radius=6,
        popup=row["station"],
        tooltip=row["station"],
        fill=True
    ).add_to(bbox_map)

bbox_coordinates = [
    [min_lat, min_lng],
    [min_lat, max_lng],
    [max_lat, max_lng],
    [max_lat, min_lng],
    [min_lat, min_lng]
]

folium.PolyLine(
    locations=bbox_coordinates,
    weight=4,
    opacity=0.8,
    popup="Bounding Box"
).add_to(bbox_map)

bbox_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea88f1ef8fc1fc2ccb7ea564118a2f2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea88f1ef8fc1fc2ccb7ea564118a2f2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea88f1ef8fc1fc2ccb7ea564118a2f2b = L.map(
#                 &quot;map_ea88f1ef8fc1fc2ccb7ea564118a2f2b&quot;,
#                 {
#                     center: [40.7427, -73.9841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67f53db7668465e94c266289c2d94484 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67f53db7668465e94c266289c2d94484.addTo(map_ea88f1ef8fc1fc2ccb7ea564118a2f2b);
#
#
#             var circle_marker_bd1c1d04df67f2ae619f8842f3f6af1d = L.circleMarker(
#                 [40.735, -73.991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea88f1ef8fc1fc2ccb7ea564118a2f2b);
#
#
#         var popup_f87b7250a6a48b399ec149024c11e099 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5226dd8576e6e0d5e463aecab90a77f1 = $(`&lt;div id=&quot;html_5226dd8576e6e0d5e463aecab90a77f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station A&lt;/div&gt;`)[0];
#                 popup_f87b7250a6a48b399ec149024c11e099.setContent(html_5226dd8576e6e0d5e463aecab90a77f1);
#
#
#
#         circle_marker_bd1c1d04df67f2ae619f8842f3f6af1d.bindPopup(popup_f87b7250a6a48b399ec149024c11e099)
#         ;
#
#
#
#
#             circle_marker_bd1c1d04df67f2ae619f8842f3f6af1d.bindTooltip(
#                 `&lt;div&gt;
#                      Station A
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_5365565b213ac9566d7af4bb42f4d7eb = L.circleMarker(
#                 [40.751, -73.977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea88f1ef8fc1fc2ccb7ea564118a2f2b);
#
#
#         var popup_866a659fef195e54b1d72bd1643c5743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_025329d21dafece354178d7c3e03243a = $(`&lt;div id=&quot;html_025329d21dafece354178d7c3e03243a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station B&lt;/div&gt;`)[0];
#                 popup_866a659fef195e54b1d72bd1643c5743.setContent(html_025329d21dafece354178d7c3e03243a);
#
#
#
#         circle_marker_5365565b213ac9566d7af4bb42f4d7eb.bindPopup(popup_866a659fef195e54b1d72bd1643c5743)
#         ;
#
#
#
#
#             circle_marker_5365565b213ac9566d7af4bb42f4d7eb.bindTooltip(
#                 `&lt;div&gt;
#                      Station B
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a5bf72e145255ecb9104627d366eba16 = L.circleMarker(
#                 [40.742, -73.985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea88f1ef8fc1fc2ccb7ea564118a2f2b);
#
#
#         var popup_dbcfe0df65ace275352ff06113c73720 = L.popup({
#   &quot;maxWidth&quot;: &quot;10

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (1.1.3)
# Requirement already satisfied: numpy>=1.24 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (2.4.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (26.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (3.0.2)
# Requirement already satisfied: pyproj>=3.5.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pandas>=2.0.0->geopandas) (2026.1)
# Requirement already satisfied: certifi in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pyogrio>=0.7.2->geopandas) (2026.5.20)
# Requirement already satisfied: six>=1.5 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
start_points = gpd.GeoDataFrame(
    trip_demo.copy(),
    geometry=gpd.points_from_xy(
        trip_demo["start_lng"],
        trip_demo["start_lat"]
    ),
    crs="EPSG:4326"
)

end_points = gpd.GeoDataFrame(
    trip_demo.copy(),
    geometry=gpd.points_from_xy(
        trip_demo["end_lng"],
        trip_demo["end_lat"]
    ),
    crs="EPSG:4326"
)

# %%
start_points[[
    "ride_id",
    "start_station",
    "end_station",
    "geometry"
]].head()
# Out:
#    ride_id start_station end_station                geometry
# 0        1     Station A   Station B  POINT (-73.991 40.735)
# 1        2     Station A   Station B  POINT (-73.991 40.735)
# 2        3     Station A   Station B  POINT (-73.991 40.735)
# 3        4     Station A   Station C  POINT (-73.991 40.735)
# 4        5     Station A   Station C  POINT (-73.991 40.735)

# %%
projected_crs = "EPSG:32618"

start_points_projected = start_points.to_crs(projected_crs)
end_points_projected = end_points.to_crs(projected_crs)

# %%
trip_demo["distance_m"] = start_points_projected.geometry.distance(
    end_points_projected.geometry
)

trip_demo["distance_km"] = trip_demo["distance_m"] / 1000

trip_demo[[
    "ride_id",
    "start_station",
    "end_station",
    "duration_min",
    "distance_m",
    "distance_km"
]].head()
# Out:
#    ride_id start_station end_station  duration_min   distance_m  distance_km
# 0        1     Station A   Station B          10.0  2133.621698     2.133622
# 1        2     Station A   Station B          13.0  2133.621698     2.133622
# 2        3     Station A   Station B          12.0  2133.621698     2.133622
# 3        4     Station A   Station C          18.0   927.671157     0.927671
# 4        5     Station A   Station C          15.0   927.671157     0.927671

# %% [markdown]
# ## Distance Summary

# %%
trip_demo[["distance_m", "distance_km"]].describe()
# Out:
#         distance_m  distance_km
# count    20.000000    20.000000
# mean   2113.717746     2.113718
# std     898.892579     0.898893
# min     927.671157     0.927671
# 25%    1665.451089     1.665451
# 50%    2133.621698     2.133622
# 75%    2282.181051     2.282181
# max    4132.274455     4.132274

# %%
route_summary = (
    trip_demo
    .groupby(
        ["start_station", "end_station"],
        as_index=False
    )
    .agg(
        number_of_rides=("ride_id", "count"),
        avg_duration_min=("duration_min", "mean"),
        median_duration_min=("duration_min", "median"),
        avg_distance_km=("distance_km", "mean"),
        median_distance_km=("distance_km", "median"),
        start_lat=("start_lat", "mean"),
        start_lng=("start_lng", "mean"),
        end_lat=("end_lat", "mean"),
        end_lng=("end_lng", "mean")
    )
    .sort_values("number_of_rides", ascending=False)
)

route_summary
# Out:
#    start_station end_station  number_of_rides  avg_duration_min  \
# 0      Station A   Station B                3         11.666667
# 1      Station A   Station C                2         16.500000
# 3      Station B   Station A                2         13.500000
# 2      Station A   Station E                1         28.000000
# 4      Station B   Station C                1         15.000000
# 5      Station B   Station D                1         18.000000
# 6      Station B   Station E                1         25.000000
# 7      Station C   Station A                1         18.000000
# 8      Station C   Station B                1         14.000000
# 9      Station C   Station D                1         20.000000
# 10     Station C   Station E                1         25.000000
# 11     Station D   Station A                1         20.000000
# 12     Station D   Station C                1         18.000000
# 13     Station D   Station E                1         20.000000
# 14     Station E   Station A                1         25.000000
# 15     Station E   Station D                1         22.000000
#
#     median_duration_min  avg_distance_km  median_distance_km  start_lat  \
# 0                  12.0         2.133622            2.133622     40.735
# 1                  16.5         0.927671            0.927671     40.735
# 3                  13.5         2.133622            2.133622     40.751
# 2                  28.0         2.795834            2.795834     40.735
# 4                  15.0         1.206023            1.206023     40.751
# 5                  18.0         2.620861            2.620861     40.751
# 6                  25.0         1.818594            1.818594     40.751
# 7                  18.0         0.927671            0.927671     40.742
# 8                  14.0         1.206023            1.206023     40.742
# 9                  20.0         2.005000            2.005000     40.742
# 10                 25.0         2.169288            2.169288     40.742
# 11                 20.0         1.936229            1.936229     40.728
# 12                 18.0         2.005000            2.005000     40.728
# 13                 20.0         4.132274            4.132274     40.728
# 14                 25.0         2.795834            2.795834     40.760
# 15                 22.0         4.132274            4.132274     40.760
#
#     start_lng  end_lat  end_lng
# 0     -73.991   40.751  -73.977
# 1     -73.991   40.742  -73.985
# 3     -73.977   40.735  -73.991
# 2     -73.991   40.760  -73.995
# 4     -73.977   40.742  -73.985
# 5     -73.977   40.728  -73.970
# 6     -73.977   40.760  -73.995
# 7     -73.985   40.735  -73.991
# 8     -73.985   40.751  -73.977
# 9     -73.985   40.728  -73.970
# 10    -73.985   40.760  -73.995
# 11    -73.970   40.735  -73.991
# 12    -73.970   40.742  -73.985
# 13    -73.970   40.760  -73.995
# 14    -73.995   40.735  -73.991
# 15    -73.995   40.728  -73.970
