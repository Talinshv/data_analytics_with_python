# %%
import pandas as pd

# %%
import os

# %%
import zipfile

# %%
# %pip install requests
# the requests library isn't installed in the Python environment your Jupyter kernel is using. It's a third-party package, so it doesn't come bundled with Python by default.
# Out:
# Requirement already satisfied: requests in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
import numpy as np

# %%
import pandas as pd

# %%
# %pip install plotly
# Out:
# Collecting plotly
#   Using cached plotly-6.8.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Using cached narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from plotly) (26.0)
# Using cached plotly-6.8.0-py3-none-any.whl (9.9 MB)
# Using cached narwhals-2.22.1-py3-none-any.whl (454 kB)
# Installing collected packages: narwhals, plotly
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed narwhals-2.22.1 plotly-6.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
# %pip install folium tqdm
# Out:
# Collecting folium
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting tqdm
#   Downloading tqdm-4.68.2-py3-none-any.whl.metadata (58 kB)
# Collecting branca>=0.6.0 (from folium)
#   Using cached branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting jinja2>=2.9 (from folium)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (2.4.4)
# Requirement already satisfied: requests in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (2.34.2)
# Collecting xyzservices (from folium)
#   Using cached xyzservices-2026.3.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: colorama in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from tqdm) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium)
#   Using cached markupsafe-3.0.3-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests->folium) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests->folium) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests->folium) (2026.5.20)
# Using cached folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading tqdm-4.68.2-py3-none-any.whl (78 kB)
# Using cached branca-0.8.2-py3-none-any.whl (26 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp313-cp313-win_amd64.whl (15 kB)
# Using cached xyzservices-2026.3.0-py3-none-any.whl (94 kB)
# Installing collected packages: xyzservices, tqdm, MarkupSafe, jinja2, branca, folium
#
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------------- -------------------------- 2/6 [MarkupSafe]
#    -------------------- ------------------- 3/6 [jinja2]
#    -------------------- ------------------- 3/6 [jinja2]
#    -------------------- ------------------- 3/6 [jinja2]
#    -------------------- ------------------- 3/6 [jinja2]
#    -------------------------- ------------- 4/6 [branca]
#    --------------------------------- ------ 5/6 [folium]
#    --------------------------------- ------ 5/6 [folium]
#    --------------------------------- ------ 5/6 [folium]
#    --------------------------------- ------ 5/6 [folium]
#    --------------------------------- ------ 5/6 [folium]
#    ---------------------------------------- 6/6 [folium]
#
# Successfully installed MarkupSafe-3.0.3 branca-0.8.2 folium-0.20.0 jinja2-3.1.6 tqdm-4.68.2 xyzservices-2026.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
# %pip install requests plotly folium tqdm
# Out:
# Requirement already satisfied: requests in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (2.34.2)
# Requirement already satisfied: plotly in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (6.8.0)
# Requirement already satisfied: folium in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (0.20.0)
# Requirement already satisfied: tqdm in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (4.68.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from requests) (2026.5.20)
# Requirement already satisfied: narwhals>=1.15.1 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from plotly) (2.22.1)
# Requirement already satisfied: packaging in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from plotly) (26.0)
# Requirement already satisfied: branca>=0.6.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (2.4.4)
# Requirement already satisfied: xyzservices in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from folium) (2026.3.0)
# Requirement already satisfied: colorama in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tqdm import tqdm

# %%
from pathlib import Path

# %%
trip_demo = pd.DataFrame({
    "ride_id": list(range(1, 21)),

    "start_station": [
        "Station A", "Station A", "Station A", "Station A", "Station A",
        "Station B", "Station B", "Station B", "Station B",
        "Station C", "Station C", "Station C",
        "Station D", "Station D", "Station D",
        "Station E", "Station E",
        "Station A", "Station B", "Station C"
    ],

    "end_station": [
        "Station B", "Station B", "Station B", "Station C", "Station C",
        "Station A", "Station A", "Station C", "Station D",
        "Station A", "Station B", "Station E",
        "Station A", "Station C", "Station E",
        "Station A", "Station D",
        "Station E", "Station E", "Station D"
    ],

    "started_at": pd.to_datetime([
        "2025-01-01 08:00", "2025-01-01 08:15", "2025-01-01 08:30",
        "2025-01-01 09:00", "2025-01-01 09:20",
        "2025-01-01 10:00", "2025-01-01 10:15", "2025-01-01 10:40",
        "2025-01-01 11:00",
        "2025-01-01 11:30", "2025-01-01 12:00", "2025-01-01 12:20",
        "2025-01-01 13:00", "2025-01-01 13:30", "2025-01-01 14:00",
        "2025-01-01 14:30", "2025-01-01 15:00",
        "2025-01-01 15:30", "2025-01-01 16:00", "2025-01-01 16:30"
    ]),

    "ended_at": pd.to_datetime([
        "2025-01-01 08:10", "2025-01-01 08:28", "2025-01-01 08:42",
        "2025-01-01 09:18", "2025-01-01 09:35",
        "2025-01-01 10:12", "2025-01-01 10:30", "2025-01-01 10:55",
        "2025-01-01 11:18",
        "2025-01-01 11:48", "2025-01-01 12:14", "2025-01-01 12:45",
        "2025-01-01 13:20", "2025-01-01 13:48", "2025-01-01 14:20",
        "2025-01-01 14:55", "2025-01-01 15:22",
        "2025-01-01 15:58", "2025-01-01 16:25", "2025-01-01 16:50"
    ]),

    "member_casual": [
        "member", "member", "casual", "member", "casual",
        "member", "member", "casual", "member",
        "casual", "member", "casual",
        "member", "casual", "member",
        "casual", "member",
        "member", "casual", "member"
    ]
})

trip_demo
# Out:
#     ride_id start_station end_station          started_at            ended_at  \
# 0         1     Station A   Station B 2025-01-01 08:00:00 2025-01-01 08:10:00
# 1         2     Station A   Station B 2025-01-01 08:15:00 2025-01-01 08:28:00
# 2         3     Station A   Station B 2025-01-01 08:30:00 2025-01-01 08:42:00
# 3         4     Station A   Station C 2025-01-01 09:00:00 2025-01-01 09:18:00
# 4         5     Station A   Station C 2025-01-01 09:20:00 2025-01-01 09:35:00
# 5         6     Station B   Station A 2025-01-01 10:00:00 2025-01-01 10:12:00
# 6         7     Station B   Station A 2025-01-01 10:15:00 2025-01-01 10:30:00
# 7         8     Station B   Station C 2025-01-01 10:40:00 2025-01-01 10:55:00
# 8         9     Station B   Station D 2025-01-01 11:00:00 2025-01-01 11:18:00
# 9        10     Station C   Station A 2025-01-01 11:30:00 2025-01-01 11:48:00
# 10       11     Station C   Station B 2025-01-01 12:00:00 2025-01-01 12:14:00
# 11       12     Station C   Station E 2025-01-01 12:20:00 2025-01-01 12:45:00
# 12       13     Station D   Station A 2025-01-01 13:00:00 2025-01-01 13:20:00
# 13       14     Station D   Station C 2025-01-01 13:30:00 2025-01-01 13:48:00
# 14       15     Station D   Station E 2025-01-01 14:00:00 2025-01-01 14:20:00
# 15       16     Station E   Station A 2025-01-01 14:30:00 2025-01-01 14:55:00
# 16       17     Station E   Station D 2025-01-01 15:00:00 2025-01-01 15:22:00
# 17       18     Station A   Station E 2025-01-01 15:30:00 2025-01-01 15:58:00
# 18       19     Station B   Station E 2025-01-01 16:00:00 2025-01-01 16:25:00
# 19       20     Station C   Station D 2025-01-01 16:30:00 2025-01-01 16:50:00
#
#    member_casual
# 0         member
# 1         member
# 2         casual
# 3         member
# 4         casual
# 5         member
# 6         member
# 7         casual
# 8         member
# 9         casual
# 10        member
# 11        casual
# 12        member
# 13        casual
# 14        member
# 15        casual
# 16        member
# 17        member
# 18        casual
# 19        member

# %%
station_coordinates = pd.DataFrame({
    "station": [
        "Station A",
        "Station B",
        "Station C",
        "Station D",
        "Station E"
    ],
    "lat": [
        40.735,
        40.751,
        40.742,
        40.728,
        40.760
    ],
    "lng": [
        -73.991,
        -73.977,
        -73.985,
        -73.970,
        -73.995
    ]
})

station_coordinates
# Out:
#      station     lat     lng
# 0  Station A  40.735 -73.991
# 1  Station B  40.751 -73.977
# 2  Station C  40.742 -73.985
# 3  Station D  40.728 -73.970
# 4  Station E  40.760 -73.995

# %%
trip_demo = (
    trip_demo
    .merge(
        station_coordinates,
        left_on="start_station",
        right_on="station",
        how="left"
    )
    .rename(columns={
        "lat": "start_lat",
        "lng": "start_lng"
    })
    .drop(columns="station")
    .merge(
        station_coordinates,
        left_on="end_station",
        right_on="station",
        how="left"
    )
    .rename(columns={
        "lat": "end_lat",
        "lng": "end_lng"
    })
    .drop(columns="station")
)

trip_demo.head()
# Out:
#    ride_id start_station end_station          started_at            ended_at  \
# 0        1     Station A   Station B 2025-01-01 08:00:00 2025-01-01 08:10:00
# 1        2     Station A   Station B 2025-01-01 08:15:00 2025-01-01 08:28:00
# 2        3     Station A   Station B 2025-01-01 08:30:00 2025-01-01 08:42:00
# 3        4     Station A   Station C 2025-01-01 09:00:00 2025-01-01 09:18:00
# 4        5     Station A   Station C 2025-01-01 09:20:00 2025-01-01 09:35:00
#
#   member_casual  start_lat  start_lng  end_lat  end_lng
# 0        member     40.735    -73.991   40.751  -73.977
# 1        member     40.735    -73.991   40.751  -73.977
# 2        casual     40.735    -73.991   40.751  -73.977
# 3        member     40.735    -73.991   40.742  -73.985
# 4        casual     40.735    -73.991   40.742  -73.985

# %%
map_center = [
    pd.concat([trip_demo["start_lat"], trip_demo["end_lat"]]).mean(),
    pd.concat([trip_demo["start_lng"], trip_demo["end_lng"]]).mean()
]

map_center
# Out:
# [np.float64(40.7427), np.float64(-73.9841)]

# %%
trip_demo["duration_min"] = (
    trip_demo["ended_at"] - trip_demo["started_at"]
).dt.total_seconds() / 60

trip_demo[[
    "ride_id",
    "start_station",
    "end_station",
    "started_at",
    "ended_at",
    "duration_min"
]].head()
# Out:
#    ride_id start_station end_station          started_at            ended_at  \
# 0        1     Station A   Station B 2025-01-01 08:00:00 2025-01-01 08:10:00
# 1        2     Station A   Station B 2025-01-01 08:15:00 2025-01-01 08:28:00
# 2        3     Station A   Station B 2025-01-01 08:30:00 2025-01-01 08:42:00
# 3        4     Station A   Station C 2025-01-01 09:00:00 2025-01-01 09:18:00
# 4        5     Station A   Station C 2025-01-01 09:20:00 2025-01-01 09:35:00
#
#    duration_min
# 0          10.0
# 1          13.0
# 2          12.0
# 3          18.0
# 4          15.0

# %%
trip_demo["date"] = trip_demo["started_at"].dt.date
trip_demo["hour"] = trip_demo["started_at"].dt.hour
trip_demo["day_name"] = trip_demo["started_at"].dt.day_name()
trip_demo["month_name"] = trip_demo["started_at"].dt.month_name()

trip_demo.head()
# Out:
#    ride_id start_station end_station          started_at            ended_at  \
# 0        1     Station A   Station B 2025-01-01 08:00:00 2025-01-01 08:10:00
# 1        2     Station A   Station B 2025-01-01 08:15:00 2025-01-01 08:28:00
# 2        3     Station A   Station B 2025-01-01 08:30:00 2025-01-01 08:42:00
# 3        4     Station A   Station C 2025-01-01 09:00:00 2025-01-01 09:18:00
# 4        5     Station A   Station C 2025-01-01 09:20:00 2025-01-01 09:35:00
#
#   member_casual  start_lat  start_lng  end_lat  end_lng  duration_min  \
# 0        member     40.735    -73.991   40.751  -73.977          10.0
# 1        member     40.735    -73.991   40.751  -73.977          13.0
# 2        casual     40.735    -73.991   40.751  -73.977          12.0
# 3        member     40.735    -73.991   40.742  -73.985          18.0
# 4        casual     40.735    -73.991   40.742  -73.985          15.0
#
#          date  hour   day_name month_name
# 0  2025-01-01     8  Wednesday    January
# 1  2025-01-01     8  Wednesday    January
# 2  2025-01-01     8  Wednesday    January
# 3  2025-01-01     9  Wednesday    January
# 4  2025-01-01     9  Wednesday    January

# %%
m = folium.Map(
    location=map_center,
    zoom_start=13
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5ca0c7e9135585a85d562e5bb5935f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5ca0c7e9135585a85d562e5bb5935f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5ca0c7e9135585a85d562e5bb5935f9 = L.map(
#                 &quot;map_c5ca0c7e9135585a85d562e5bb5935f9&quot;,
#                 {
#                     center: [40.7427, -73.9841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b65ef78c8ce171ec884e7dcc9b51705 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b65ef78c8ce171ec884e7dcc9b51705.addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for _, row in station_coordinates.iterrows():
    folium.Marker(
        location=[row["lat"], row["lng"]],
        popup=row["station"]
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5ca0c7e9135585a85d562e5bb5935f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5ca0c7e9135585a85d562e5bb5935f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5ca0c7e9135585a85d562e5bb5935f9 = L.map(
#                 &quot;map_c5ca0c7e9135585a85d562e5bb5935f9&quot;,
#                 {
#                     center: [40.7427, -73.9841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b65ef78c8ce171ec884e7dcc9b51705 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b65ef78c8ce171ec884e7dcc9b51705.addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#             tile_layer_2b65ef78c8ce171ec884e7dcc9b51705.addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#             var marker_f8487c429ad9169af14550e6272bbb2c = L.marker(
#                 [40.735, -73.991],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_52ad7a2169dc4fda08509b018a2c4800 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49218ab1d21e7431e33f1291d4573f02 = $(`&lt;div id=&quot;html_49218ab1d21e7431e33f1291d4573f02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station A&lt;/div&gt;`)[0];
#                 popup_52ad7a2169dc4fda08509b018a2c4800.setContent(html_49218ab1d21e7431e33f1291d4573f02);
#
#
#
#         marker_f8487c429ad9169af14550e6272bbb2c.bindPopup(popup_52ad7a2169dc4fda08509b018a2c4800)
#         ;
#
#
#
#
#             var marker_01e3a171d6d8239b414cb05c16343303 = L.marker(
#                 [40.751, -73.977],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_749cb58051035b2c4987eedf57eeeefa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cd12c134e9200fb8f7a34bf1da04eca = $(`&lt;div id=&quot;html_1cd12c134e9200fb8f7a34bf1da04eca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station B&lt;/div&gt;`)[0];
#                 popup_749cb58051035b2c4987eedf57eeeefa.setContent(html_1cd12c134e9200fb8f7a34bf1da04eca);
#
#
#
#         marker_01e3a171d6d8239b414cb05c16343303.bindPopup(popup_749cb58051035b2c4987eedf57eeeefa)
#         ;
#
#
#
#
#             var marker_b417bc4bfa7ee23b42680e0909451923 = L.marker(
#                 [40.742, -73.985],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_9078ece60681ca87a9ff732362140f15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35c8ab23df8951d16081a8860cd69f41 = $(`&lt;div id=&quot;html_35c8ab23df8951d16081a8860cd69f41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station C&lt;/div&gt;`)[0];
#                 popup_9078ece60681ca87a9ff732362140f15.setContent(html_35c8ab23df8951d16081a8860cd69f41);
#
#
#
#         marker_b417bc4bfa7ee23b42680e0909451923.bindPopup(popup_9078ece60681ca87a9ff732362140f15)
#         ;
#
#
#
#
#             var marker_fafa2211be736a068e369e4e815b1d17 = L.marker(
#                 [40.728, -73.97],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_b97f501853eb1e6befad15d0927e27be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ee95b19416b353efbbf00f79c4fa511 = $(`&lt;div id=&quot;html_6ee95b19416b353efbbf00f79c4fa511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station D&lt;/div&gt;`)[0];
#                 popup_b97f501853eb1e6befad15d0927e27be.setContent(html_6ee95b19416b353efbbf00f79c4fa511);
#
#
#
#         marker_fafa2211be736a068e369e4e815b1d17.bindPopup(popup_b97f501853eb1e6befad15d0927e27be)
#         ;
#
#
#
#
#             var marker_ab09bb46663d50df8da609d52cbc0451 = L.marker(
#                 [40.76, -73.995],
#                 {
# }
#             ).addTo(map_c5ca0c7e9135585a85d562e5bb5935f9);
#
#
#         var popup_f0a64e5b9fec3b5fc19d49b047175a52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2003b988e6832dcac9cf9d38d62c638c = $(`&lt;div id=&quot;html_2003b988e6832dcac9cf9d38d62c638c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station E&lt;/div&gt;`)[0];
#                 popup_f0a64e5b9fec3b5fc19d49b047175a52.setContent(html_2003b988e

# %%
m = folium.Map(
    location=[40.74, -73.99],
    zoom_start=13
)

start_point = [trip_demo.loc[0, "start_lat"], trip_demo.loc[0, "start_lng"]]
end_point = [trip_demo.loc[0, "end_lat"], trip_demo.loc[0, "end_lng"]]

folium.Marker(start_point, popup="Start").add_to(m)
folium.Marker(end_point, popup="End").add_to(m)

folium.PolyLine(
    locations=[start_point, end_point],
    weight=5,
    opacity=0.8
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e3c718c40adbe9864778d6c938fa571 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e3c718c40adbe9864778d6c938fa571&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e3c718c40adbe9864778d6c938fa571 = L.map(
#                 &quot;map_5e3c718c40adbe9864778d6c938fa571&quot;,
#                 {
#                     center: [40.74, -73.99],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02adf561ce56eb5ba74083c691832cb5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02adf561ce56eb5ba74083c691832cb5.addTo(map_5e3c718c40adbe9864778d6c938fa571);
#
#
#             var marker_d4bdaaf24f7c48dc055547d9dda8a8db = L.marker(
#                 [40.735, -73.991],
#                 {
# }
#             ).addTo(map_5e3c718c40adbe9864778d6c938fa571);
#
#
#         var popup_e9ad34d29c6cd7bce08e3350d0345da3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84866a737760b0f729098cf4fda8d38a = $(`&lt;div id=&quot;html_84866a737760b0f729098cf4fda8d38a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_e9ad34d29c6cd7bce08e3350d0345da3.setContent(html_84866a737760b0f729098cf4fda8d38a);
#
#
#
#         marker_d4bdaaf24f7c48dc055547d9dda8a8db.bindPopup(popup_e9ad34d29c6cd7bce08e3350d0345da3)
#         ;
#
#
#
#
#             var marker_0fd99631675221e294c3ed4d35c25931 = L.marker(
#                 [40.751, -73.977],
#                 {
# }
#             ).addTo(map_5e3c718c40adbe9864778d6c938fa571);
#
#
#         var popup_da849d4e5c9851c842508bb3921493bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24e0e77778196d359a8b0db9012f56f9 = $(`&lt;div id=&quot;html_24e0e77778196d359a8b0db9012f56f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_da849d4e5c9851c842508bb3921493bb.setContent(html_24e0e77778196d359a8b0db9012f56f9);
#
#
#
#         marker_0fd99631675221e294c3ed4d35c25931.bindPopup(popup_da849d4e5c9851c842508bb3921493bb)
#         ;
#
#
#
#
#             var poly_line_e53c591cd7cf14863c7ec42c35d28274 = L.polyline(
#                 [[40.735, -73.991], [40.751, -73.977]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_5e3c718c40adbe9864778d6c938fa571);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
flow_data = (
    trip_demo
    .groupby(
        ["start_station", "end_station"],
        as_index=False
    )
    .agg(
        number_of_rides=("ride_id", "count"),
        avg_duration_min=("duration_min", "mean"),
        start_lat=("start_lat", "mean"),
        start_lng=("start_lng", "mean"),
        end_lat=("end_lat", "mean"),
        end_lng=("end_lng", "mean")
    )
    .sort_values("number_of_rides", ascending=False)
)

flow_data
# Out:
#    start_station end_station  number_of_rides  avg_duration_min  start_lat  \
# 0      Station A   Station B                3         11.666667     40.735
# 1      Station A   Station C                2         16.500000     40.735
# 3      Station B   Station A                2         13.500000     40.751
# 2      Station A   Station E                1         28.000000     40.735
# 4      Station B   Station C                1         15.000000     40.751
# 5      Station B   Station D                1         18.000000     40.751
# 6      Station B   Station E                1         25.000000     40.751
# 7      Station C   Station A                1         18.000000     40.742
# 8      Station C   Station B                1         14.000000     40.742
# 9      Station C   Station D                1         20.000000     40.742
# 10     Station C   Station E                1         25.000000     40.742
# 11     Station D   Station A                1         20.000000     40.728
# 12     Station D   Station C                1         18.000000     40.728
# 13     Station D   Station E                1         20.000000     40.728
# 14     Station E   Station A                1         25.000000     40.760
# 15     Station E   Station D                1         22.000000     40.760
#
#     start_lng  end_lat  end_lng
# 0     -73.991   40.751  -73.977
# 1     -73.991   40.742  -73.985
# 3     -73.977   40.735  -73.991
# 2     -73.991   40.760  -73.995
# 4     -73.977   40.742  -73.985
# 5     -73.977   40.728  -73.970
# 6     -73.977   40.760  -73.995
# 7     -73.985   40.735  -73.991
# 8     -73.985   40.751  -73.977
# 9     -73.985   40.728  -73.970
# 10    -73.985   40.760  -73.995
# 11    -73.970   40.735  -73.991
# 12    -73.970   40.742  -73.985
# 13    -73.970   40.760  -73.995
# 14    -73.995   40.735  -73.991
# 15    -73.995   40.728  -73.970

# %%
flow_map = folium.Map(
    location=map_center,
    zoom_start=13,
    tiles="CartoDB positron"
)

for _, row in station_coordinates.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lng"]],
        radius=6,
        popup=row["station"],
        tooltip=row["station"],
        fill=True
    ).add_to(flow_map)

max_rides = flow_data["number_of_rides"].max()

for _, row in flow_data.iterrows():

    start_point = [row["start_lat"], row["start_lng"]]
    end_point = [row["end_lat"], row["end_lng"]]

    line_width = 1 + 7 * row["number_of_rides"] / max_rides

    popup_text = (
        f"<b>{row['start_station']} → {row['end_station']}</b><br>"
        f"Number of rides: {row['number_of_rides']}<br>"
        f"Average duration: {row['avg_duration_min']:.1f} minutes"
    )

    folium.PolyLine(
        locations=[start_point, end_point],
        weight=line_width,
        opacity=0.7,
        popup=popup_text,
        tooltip=f"{row['start_station']} → {row['end_station']}"
    ).add_to(flow_map)

flow_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fb5b8e8476cb6c02f9030d275a2633f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fb5b8e8476cb6c02f9030d275a2633f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fb5b8e8476cb6c02f9030d275a2633f = L.map(
#                 &quot;map_9fb5b8e8476cb6c02f9030d275a2633f&quot;,
#                 {
#                     center: [40.7427, -73.9841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_470bf3a85de13c256d30151420851168 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_470bf3a85de13c256d30151420851168.addTo(map_9fb5b8e8476cb6c02f9030d275a2633f);
#
#
#             var circle_marker_83b92f2a9c2cd49158ae93d00c422945 = L.circleMarker(
#                 [40.735, -73.991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fb5b8e8476cb6c02f9030d275a2633f);
#
#
#         var popup_62bbc5e1b8e505fee9ced7ba6eace89e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6962a2bad49497df0f346ff6475c9067 = $(`&lt;div id=&quot;html_6962a2bad49497df0f346ff6475c9067&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station A&lt;/div&gt;`)[0];
#                 popup_62bbc5e1b8e505fee9ced7ba6eace89e.setContent(html_6962a2bad49497df0f346ff6475c9067);
#
#
#
#         circle_marker_83b92f2a9c2cd49158ae93d00c422945.bindPopup(popup_62bbc5e1b8e505fee9ced7ba6eace89e)
#         ;
#
#
#
#
#             circle_marker_83b92f2a9c2cd49158ae93d00c422945.bindTooltip(
#                 `&lt;div&gt;
#                      Station A
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_913839cfcb26026c0afa1578adf33eef = L.circleMarker(
#                 [40.751, -73.977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fb5b8e8476cb6c02f9030d275a2633f);
#
#
#         var popup_22a622fcb29ee1921d7940d40c402d5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1271c9ef4ace0a00f1f344eebd1d03c8 = $(`&lt;div id=&quot;html_1271c9ef4ace0a00f1f344eebd1d03c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station B&lt;/div&gt;`)[0];
#                 popup_22a622fcb29ee1921d7940d40c402d5c.setContent(html_1271c9ef4ace0a00f1f344eebd1d03c8);
#
#
#
#         circle_marker_913839cfcb26026c0afa1578adf33eef.bindPopup(popup_22a622fcb29ee1921d7940d40c402d5c)
#         ;
#
#
#
#
#             circle_marker_913839cfcb26026c0afa1578adf33eef.bindTooltip(
#                 `&lt;div&gt;
#                      Station B
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_448dc4e052af102d1ddceffda3b81f91 = L.circleMarker(
#                 [40.742, -73.985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fb5b8e8476cb6c02f9030d275a2633f);
#
#
#         var popup_a6b523d5a17763f8288b0421d6467ad7 = L.popup({
#   &quot;maxWidth&quot;: &quot;10

# %%
min_lat = min(trip_demo["start_lat"].min(), trip_demo["end_lat"].min())
max_lat = max(trip_demo["start_lat"].max(), trip_demo["end_lat"].max())

min_lng = min(trip_demo["start_lng"].min(), trip_demo["end_lng"].min())
max_lng = max(trip_demo["start_lng"].max(), trip_demo["end_lng"].max())

bounding_box = pd.DataFrame({
    "metric": ["min_lat", "max_lat", "min_lng", "max_lng"],
    "value": [min_lat, max_lat, min_lng, max_lng]
})

bounding_box
# Out:
#     metric   value
# 0  min_lat  40.728
# 1  max_lat  40.760
# 2  min_lng -73.995
# 3  max_lng -73.970

# %%
bbox_map = folium.Map(
    location=map_center,
    zoom_start=13,
    tiles="CartoDB positron"
)

for _, row in station_coordinates.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lng"]],
        radius=6,
        popup=row["station"],
        tooltip=row["station"],
        fill=True
    ).add_to(bbox_map)

bbox_coordinates = [
    [min_lat, min_lng],
    [min_lat, max_lng],
    [max_lat, max_lng],
    [max_lat, min_lng],
    [min_lat, min_lng]
]

folium.PolyLine(
    locations=bbox_coordinates,
    weight=4,
    opacity=0.8,
    popup="Bounding Box"
).add_to(bbox_map)

bbox_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7dd080499cc7dcca63a13f8de33456df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7dd080499cc7dcca63a13f8de33456df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7dd080499cc7dcca63a13f8de33456df = L.map(
#                 &quot;map_7dd080499cc7dcca63a13f8de33456df&quot;,
#                 {
#                     center: [40.7427, -73.9841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9817e95decd491a705fd99b12a8b25e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9817e95decd491a705fd99b12a8b25e.addTo(map_7dd080499cc7dcca63a13f8de33456df);
#
#
#             var circle_marker_9f76b3cd5edf35983e244596908c265e = L.circleMarker(
#                 [40.735, -73.991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7dd080499cc7dcca63a13f8de33456df);
#
#
#         var popup_fb2b05730023b278f088d27f93f9f306 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79e16e8cc6d61d24b7040e40eb988dcb = $(`&lt;div id=&quot;html_79e16e8cc6d61d24b7040e40eb988dcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station A&lt;/div&gt;`)[0];
#                 popup_fb2b05730023b278f088d27f93f9f306.setContent(html_79e16e8cc6d61d24b7040e40eb988dcb);
#
#
#
#         circle_marker_9f76b3cd5edf35983e244596908c265e.bindPopup(popup_fb2b05730023b278f088d27f93f9f306)
#         ;
#
#
#
#
#             circle_marker_9f76b3cd5edf35983e244596908c265e.bindTooltip(
#                 `&lt;div&gt;
#                      Station A
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_3eadc0c58639556cc9cc3f547fd49926 = L.circleMarker(
#                 [40.751, -73.977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7dd080499cc7dcca63a13f8de33456df);
#
#
#         var popup_8be0187d93adf43d2e8778d2f5b417fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e24613fe6cbe13aa9aab50287d0e0c7a = $(`&lt;div id=&quot;html_e24613fe6cbe13aa9aab50287d0e0c7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station B&lt;/div&gt;`)[0];
#                 popup_8be0187d93adf43d2e8778d2f5b417fb.setContent(html_e24613fe6cbe13aa9aab50287d0e0c7a);
#
#
#
#         circle_marker_3eadc0c58639556cc9cc3f547fd49926.bindPopup(popup_8be0187d93adf43d2e8778d2f5b417fb)
#         ;
#
#
#
#
#             circle_marker_3eadc0c58639556cc9cc3f547fd49926.bindTooltip(
#                 `&lt;div&gt;
#                      Station B
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_4633a76365a566a753405158e274c777 = L.circleMarker(
#                 [40.742, -73.985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7dd080499cc7dcca63a13f8de33456df);
#
#
#         var popup_9c3b1618e5be52661f476248a3e476a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;10

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.1.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (2.4.4)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.12.1-cp313-cp313-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: packaging in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (26.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (3.0.2)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pandas>=2.0.0->geopandas) (2026.1)
# Requirement already satisfied: certifi in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pyogrio>=0.7.2->geopandas) (2026.5.20)
# Requirement already satisfied: six>=1.5 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Downloading geopandas-1.1.3-py3-none-any.whl (342 kB)
# Downloading pyogrio-0.12.1-cp313-cp313-win_amd64.whl (22.9 MB)
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    - -------------------------------------- 0.8/22.9 MB 3.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.8/22.9 MB 3.8 MB/s eta 0:00:06
#    - -------------------------------------- 1.0/22.9 MB 1.6 MB/s eta 0:00:14
#    -- ------------------------------------- 1.6/22.9 MB 1.6 MB/s eta 0:00:14
#    --- ------------------------------------ 1.8/22.9 MB 1.6 MB/s eta 0:00:14
#    --- ------------------------------------ 1.8/22.9 MB 1.6 MB/s eta 0:00:14
#    --- ------------------------------------ 2.1/22.9 MB 1.4 MB/s eta 0:00:15
#    ---- ----------------------------------- 2.4/22.9 MB 1.4 MB/s eta 0:00:16
#    ---- ----------------------------------- 2.6/22.9 MB 1.3 MB/s eta 0:00:16
#    ----- ---------------------------------- 2.9/22.9 MB 1.3 MB/s eta 0:00:16
#    ----- ---------------------------------- 3.1/22.9 MB 1.3 MB/s eta 0:00:16
#    ----- ---------------------------------- 3.4/22.9 MB 1.3 MB/s eta 0:00:16
#    ------ --------------------------------- 3.7/22.9 MB 1.2 MB/s eta 0:00:16
#    ------ --------------------------------- 3.7/22.9 MB 1.2 MB/s eta 0:00:16
#    ------ --------------------------------- 3.9/22.9 MB 1.2 MB/s eta 0:00:16
#    ------- -------------------------------- 4.2/22.9 MB 1.2 MB/s eta 0:00:16
#    ------- -------------------------------- 4.5/22.9 MB 1.2 MB/s eta 0:00:15
#    -------- ------------------------------- 4.7/22.9 MB 1.2 MB/s eta 0:00:15
#    -------- ------------------------------- 5.0/22.9 MB 1.2 MB/s eta 0:00:15
#    --------- ------------------------------ 5.2/22.9 MB 1.2 MB/s eta 0:00:15
#    ---------- ----------------------------- 5.8/22.9 MB 1.2 MB/s eta 0:00:14
#    ---------- ----------------------------- 6.0/22.9 MB 1.2 MB/s eta 0:00:14
#    ---------- ----------------------------- 6.0/22.9 MB 1.2 MB/s eta 0:00:14
#    ---------- ----------------------------- 6.3/22.9 MB 1.2 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.6/22.9 MB 1.2 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.6/22.9 MB 1.2 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.6/22.9 MB 1.2 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.6/22.9 MB 1.2 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.6/22.9 MB 1.2 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.6/22.9 MB 1.2 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.6/22.9 MB 1.2 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.6/22.9 MB 1.2 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.8/22.9 MB 959.3 kB/s eta 0:00:17
#    ----------- ---------------------------- 6.8/22.9 MB 959.3 kB/s eta 0:00:17
#    ------------ --------------------------- 7.1/22.9 MB 934.7 kB/s eta 0:00:17
#    ------------ --------------------------- 7.1/22.9 MB 934.7 kB/s eta 0:00:17
#    ------------ --------------------------- 7.3/22.9 MB 921.1 kB/s eta 0:00:17
#    ------------- -------------------------- 7.6/22.9 MB 912.6 kB/s eta 0:00:17
#    ------------- -------------------------- 7.6/22.9 MB 912.6 kB/s eta 0:00:17
#    ------------- -------------------------- 7.9/22.9 MB 905.1 kB/s eta 0:00:17
#    ------------- -------------------------- 7.9/22.9 MB 905.1 kB/s eta 0:00:17
#    -------------- ------------------------- 8.1/22.9 MB 894.5 kB/s eta 0:00:17
#    -------------- ------------------------- 8.4/22.9 MB 889.3 kB/s eta 0:00:17
#    -------------- ------------------------- 8.4/22.9 MB 889.3 kB/s eta 0:00:17
#    --------------- ------------------------ 8.7/22.9 MB 886.1 kB/s eta 0:00:17
#    --------------- ------------------------ 8.7/22.9 MB 886.1 kB/s eta 0:00:17
#    --------------- ------------------------ 8.9/22.9 MB 883.9 kB/s eta 0:00:16
#    ---------------- ----------------------- 9.2/22.9 MB 883.5 kB/s eta 0:00:16
#    ---------------- ----------------------- 9.4/22.9 MB 882.7 kB/s eta 0:00:16
#    ---------------- ----------------------- 9.4/22.9 MB 882.7 kB/s eta 0:00:16
#    ---------------- ----------------------- 9.7/22.9 MB 884.6 kB/s eta 0:00:15
#    ----------------- ---------------------- 10.0/22.9 MB 886.4 kB/s eta 0:00:15
#    ----------------- ---------------------- 10.2/22.9 MB 889.1 kB/s eta 0:00:15
#    ------------------ --------------------- 10.5/22.9 MB 893.0 kB/s eta 0:00:14
#    ------------------ --------------------- 10.5/22.9 MB 893.0 kB/s eta 0:00:14
#    ------------------ --------------------- 10.7/22.9 MB 896.8 kB/s eta 0:00:14
#    ------------------- -------------------- 11.0/22.9 MB 901.0 kB/s eta 0:00:14
#    ------------------- -------------------- 11.3/22.9 MB 905.5 kB/s eta 0:00:13
#    -------------------- ------------------- 11.5/22.9 MB 907.8 kB/s eta 0:00:13
#    -------------------- ------------------- 11.8/22.9 MB 910.9 kB/s eta 0:00:13
#    --------------------- ------------------ 12.1/22.9 MB 916.7 kB/s eta 0:00:12
#    --------------------- ------------------ 12.3/22.9 MB 921.9 kB/s eta 0:00:12
#    --------------------- ------------------ 12.6/22.9 MB 927.4 kB/s eta 0:00:12
#    ---------------------- ----------------- 12.8/22.9 MB 933.4 kB/s eta 0:00:11
#    ---------------------- ----------------- 13.1/22.9 MB 938.5 kB/s eta 0:00:11
#    ----------------------- ---------------- 13.4/22.9 MB 943.2 kB/s eta 0:00:11
#    ----------------------- ---------------- 13.6/22.9 MB 948.8 kB/s eta 0:00:10
#    ------------------------ --------------- 13.9/22.9 MB 952.7 kB/s eta 0:00:10
#    ------------------------ --------------- 14.2/22.9 MB 955.0 kB/s eta 0:00:10
#    ------------------------ --------------- 14.2/22.9 MB 955.0 kB/s eta 0:00:10
#    ------------------------- -------------- 14.4/22.9 MB 948.6 kB/s eta 0:00:09
#    ------------------------- -------------- 14.7/22.9 MB 943.6 kB/s eta 0:00:09
#    ------------------------- -------------- 14.7/22.9 MB 943.6 kB/s eta 0:00:09
#    -------------------------- ------------- 14.9/22.9 MB 942.0 kB/s eta 0:00:09
#    -------------------------- ------------- 15.2/22.9 MB 939.5 kB/s eta 0:00:09
#    -------------------------- ------------- 15.2/22.9 MB 939.5 kB/s eta 0:00:09
#    -------------------------- ------------- 15.5/22.9 MB 937.5 kB/s eta 0:00:08
#    --------------------------- ------------ 15.7/22.9 MB 936.6 kB/s eta 0:00:08
#    --------------------------- ------------ 15.7/22.9 MB 936.6 kB/s eta 0:00:08
#    --------------------------- ------------ 16.0/22.9 MB 936.8 kB/s eta 0:00:08
#    ---------------------------- ----------- 16.3/22.9 MB 936.8 kB/s eta 0:00:08
#    ---------------------------- ----------- 16.5/22.9 MB 937.8 kB/s eta 0:00:07
#    ----------------------------- ---------- 16.8/22.9 MB 939.1 kB/s eta 0:00:07
#    ----------------------------- ---------- 16.8/22.9 MB 939.1 kB/s eta 0:00:07
#    ----------------------------- ---------- 17.0/22.9 MB 940.9 kB/s eta 0:00:07
#    ------------------------------ --------- 17.3/22.9 MB 942.6 kB/s eta 0:00:06
#    ------------------------------ --------- 17.6/22.9 MB 944.8 kB/s eta 0:00:06
#    ------------------------------- -------- 17.8/22.9 MB 947.3 kB/s eta 0:00:06
#    ------------------------------- -------- 18.1/22.9 MB 950.2 kB/s eta 0:00:06
#    -------------------------------- ------- 18.4/22.9 MB 952.5 kB/s eta 0:00:05
#    -------------------------------- ------- 18.6/22.9 MB 955.9 kB/s eta 0:00:05
#    -------------------------------- ------- 18.9/22.9 MB 958.8 kB/s eta 0:00:05
#    --------------------------------- ------ 19.1/22.9 MB 958.7 kB/s eta 0:00:04
#    --------------------------------- ------ 19.4/22.9 MB 961.7 kB/s eta 0:00:04
#    ---------------------------------- ----- 19.7/22.9 MB 965.1 kB/s eta 0:00:04
#    ---------------------------------- ----- 19.9/22.9 MB 967.4 kB/s eta 0:00:04
#    ----------------------------------- ---- 20.2/22.9 MB 969.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 20.2/22.9 MB 969.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 20.4/22.9 MB 970.1 kB/s eta 0:00:03
#    ------------------------------------ --- 20.7/22.9 MB 973.0 kB/s eta 0:00:03
#    ------------------------------------ --- 21.0/22.9 MB 975.3 kB/s eta 0:00:03
#    ------------------------------------- -- 21.2/22.9 MB 976.9 kB/s eta 0:00:02
#    ------------------------------------- -- 21.5/22.9 MB 973.3 kB/s eta 0:00:02
#    ------------------------------------- -- 21.8/22.9 MB 975.7 kB/s eta 0:00:02
#    -------------------------------------- - 22.0/22.9 MB 979.4 kB/s eta 0:00:01
#    -------------------------------------- - 22.3/22.9 MB 983.2 kB/s eta 0:00:01
#    -------------------------------------- - 22.3/22.9 MB 983.2 kB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 985.4 kB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 985.4 kB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 980.0 kB/s  0:00:23
# Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.3 MB 1.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 0.8/6.3 MB 1.0 MB/s eta 0:00:06
#    ------ --------------------------------- 1.0/6.3 MB 1.0 MB/s eta 0:00:06
#    ------ --------------------------------- 1.0/6.3 MB 1.0 MB/s eta 0:00:06
#    -------- ------------------------------- 1.3/6.3 MB 1.0 MB/s eta 0:00:05
#    --------- ------------------------------ 1.6/6.3 MB 1.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 1.8/6.3 MB 1.0 MB/s eta 0:00:05
#    ------------- -------------------------- 2.1/6.3 MB 1.0 MB/s eta 0:00:05
#    -------------- ------------------------- 2.4/6.3 MB 1.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 2.6/6.3 MB 1.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 2.6/6.3 MB 1.1 MB/s eta 0:00:04
#    ------------------- -------------------- 3.1/6.3 MB 1.1 MB/s eta 0:00:03
#    --------------------- ------------------ 3.4/6.3 MB 1.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 3.7/6.3 MB 1.1 MB/s eta 0:00:03
#    ------------------------ --------------- 3.9/6.3 MB 1.1 MB/s eta 0:00:03
#    -------------------------- ------------- 4.2/6.3 MB 1.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.5/6.3 MB 1.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.5/6.3 MB 1.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 4.7/6.3 MB 1.1 MB/s eta 0:00:02
#    ------------------------------- -------- 5.0/6.3 MB 1.1 MB/s eta 0:00:02
#    ------------------------------- -------- 5.0/6.3 MB 1.1 MB/s eta 0:00:02
#    --------------------------------- ------ 5.2/6.3 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 5.8/6.3 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.3 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.3 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 1.0 MB/s  0:00:06
# Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 928.5 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.7 MB 928.5 kB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.7 MB 950.3 kB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 957.7 kB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 954.4 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 971.3 kB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 959.3 kB/s  0:00:01
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
#
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ---------------------------------------- 4/4 [geopandas]
#
# Successfully installed geopandas-1.1.3 pyogrio-0.12.1 pyproj-3.7.2 shapely-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
start_points = gpd.GeoDataFrame(
    trip_demo.copy(),
    geometry=gpd.points_from_xy(
        trip_demo["start_lng"],
        trip_demo["start_lat"]
    ),
    crs="EPSG:4326"
)

end_points = gpd.GeoDataFrame(
    trip_demo.copy(),
    geometry=gpd.points_from_xy(
        trip_demo["end_lng"],
        trip_demo["end_lat"]
    ),
    crs="EPSG:4326"
)

# %%
start_points[[
    "ride_id",
    "start_station",
    "end_station",
    "geometry"
]].head()
# Out:
#    ride_id start_station end_station                geometry
# 0        1     Station A   Station B  POINT (-73.991 40.735)
# 1        2     Station A   Station B  POINT (-73.991 40.735)
# 2        3     Station A   Station B  POINT (-73.991 40.735)
# 3        4     Station A   Station C  POINT (-73.991 40.735)
# 4        5     Station A   Station C  POINT (-73.991 40.735)

# %%
projected_crs = "EPSG:32618"

start_points_projected = start_points.to_crs(projected_crs)
end_points_projected = end_points.to_crs(projected_crs)

# %%
trip_demo["distance_m"] = start_points_projected.geometry.distance(
    end_points_projected.geometry
)

trip_demo["distance_km"] = trip_demo["distance_m"] / 1000

trip_demo[[
    "ride_id",
    "start_station",
    "end_station",
    "duration_min",
    "distance_m",
    "distance_km"
]].head()
# Out:
#    ride_id start_station end_station  duration_min   distance_m  distance_km
# 0        1     Station A   Station B          10.0  2133.621698     2.133622
# 1        2     Station A   Station B          13.0  2133.621698     2.133622
# 2        3     Station A   Station B          12.0  2133.621698     2.133622
# 3        4     Station A   Station C          18.0   927.671157     0.927671
# 4        5     Station A   Station C          15.0   927.671157     0.927671
