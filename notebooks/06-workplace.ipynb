# %%
import pandas as pd
df_customers_dummy = pd.DataFrame({
    "customer": ["A", "B", "C", "D", "E"],
    "age": [22, 35, 47, 63, 29],
    "income": [18000, 42000, 72000, 95000, 25000]
})

df_customers_dummy
# Out:
#   customer  age  income
# 0        A   22   18000
# 1        B   35   42000
# 2        C   47   72000
# 3        D   63   95000
# 4        E   29   25000

# %%
import pandas as pd

def generate_customer_data():
    """
    Creates and returns a DataFrame of dummy customers.
    """
    df = pd.DataFrame({
        "customer": ["A", "B", "C", "D", "E"],
        "age": [22, 35, 47, 63, 29],
        "income": [18000, 42000, 72000, 95000, 25000]
    })
    return df
