# %%
pip install pandas geopandas sqlalchemy psycopg2-binary geoalchemy2 python-dotenv
# Out:
# Requirement already satisfied: pandas in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (3.0.2)
# Requirement already satisfied: geopandas in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (1.1.3)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.51-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.12-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Collecting geoalchemy2
#   Downloading geoalchemy2-0.20.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (26.0)
# Requirement already satisfied: pyproj>=3.5.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from geopandas) (2.1.2)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.5.4-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy)
#   Downloading typing_extensions-4.16.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: certifi in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from pyogrio>=0.7.2->geopandas) (2026.5.20)
# Requirement already satisfied: six>=1.5 in c:\Users\ArmTa\miniconda3\envs\aca\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading sqlalchemy-2.0.51-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 457.6 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.1 MB 457.6 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 523.1 kB/s eta 0:00:03
#    ------------------- -------------------- 1.0/2.1 MB 564.7 kB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.1 MB 564.7 kB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.1 MB 564.7 kB/s eta 0:00:02
#    ------------------------ --------------- 1.3/2.1 MB 562.2 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.6/2.1 MB 593.2 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 593.2 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 622.8 kB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 628.1 kB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 629.2 kB/s  0:00:03
# Downloading psycopg2_binary-2.9.12-cp313-cp313-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 1.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 0.8/2.8 MB 1.1 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.8 MB 1.1 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.8 MB 1.1 MB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.8 MB 996.4 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.8 MB 1.0 MB/s eta 0:00:02
#    -------------------------- ------------- 1.8/2.8 MB 974.7 kB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 974.7 kB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.8 MB 964.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.8 MB 950.1 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.8 MB 950.1 kB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 920.5 kB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 897.3 kB/s  0:00:03
# Downloading geoalchemy2-0.20.0-py3-none-any.whl (96 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading greenlet-3.5.4-cp313-cp313-win_amd64.whl (247 kB)
# Downloading typing_extensions-4.16.0-py3-none-any.whl (45 kB)
# Installing collected packages: typing-extensions, python-dotenv, psycopg2-binary, greenlet, sqlalchemy, geoalchemy2
#
#    ---------------------------------------- 0/6 [typing-extensions]
#    ------ --------------------------------- 1/6 [python-dotenv]
#    ------------- -------------------------- 2/6 [psycopg2-binary]
#    ------------- -------------------------- 2/6 [psycopg2-binary]
#    ------------- -------------------------- 2/6 [psycopg2-binary]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    --------------------------------- ------ 5/6 [geoalchemy2]
#    --------------------------------- ------ 5/6 [geoalchemy2]
#    --------------------------------- ------ 5/6 [geoalchemy2]
#    ---------------------------------------- 6/6 [geoalchemy2]
#
# Successfully installed geoalchemy2-0.20.0 greenlet-3.5.4 psycopg2-binary-2.9.12 python-dotenv-1.2.2 sqlalchemy-2.0.51 typing-extensions-4.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import geopandas as gpd
from zipfile import ZipFile

from pathlib import Path
from sqlalchemy import create_engine, text
from geoalchemy2 import Geometry

# %%
DATA_DIR = Path("../data/citibike/JC")

citibike_path = DATA_DIR / "JC2025.csv"
weather_path = DATA_DIR / "jersey_weather_2025.csv"
neighborhood_path = DATA_DIR / "jersey-city-neighborhoods.geojson"
