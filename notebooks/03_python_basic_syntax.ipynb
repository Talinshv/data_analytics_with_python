# %% [markdown]
# # Arithmetic Operations

# %%
r = 100    # revenue
t = 0.2    # tax 

total = r * (1 + t)   #  total revenue including tax
total
# Out:
# 120.0

# %%
100 > 50       #Greater Than (>)
100 == 50      #Equal To (==)
100 != 50      #Not Equal To (!=)
# Out:
# True

# %%
print((100 > 50) and (20 < 30))
# Out:
# True

# %% [markdown]
# # Basic Data Structures

# %% [markdown]
# ## List [ ]

# %%
sales = [100, 200, 150, 200]
sales
# Out:
# [100, 200, 150, 200]

# %%
sales[0]   # gets the FIRST item → 100
sales[-1]  # gets the LAST item → 200
# Out:
# 200

# %% [markdown]
# Indexing starts at 0 in Python.
#
# Negative index -1 means start from the end.
#
# Both returned 200 because sales[0]=100 was not printed, only sales[-1]=200 was shown.

# %%
sales.append(300)   # adds 300 to the END of the list
sales[1] = 250      # changes index 1 (was 200) to 250
sales
# Out:
# [100, 250, 150, 200, 300, 300]

# %%
len(sales)   # counts how many items → 6
# Out:
# 6

# %%
total = 0               #This creates a variable to act as a "bucket" to hold our sum. We start at zero.
for value in sales:     #This tells the computer to look at the list called sales and pick up each number one by one.
    total += value      #This is a shortcut for Reassignment."Take the current total,add the new value to it,and put the result back into total"

total
# Out:
# 1300

# %% [markdown]
# ## Tuple ( )

# %% [markdown]
# Tuple is a specific way of grouping data together in Python.
#
# While it looks similar to a standard list, it has one superpower: immutability.
#
# A tuple is a collection of items that are ordered and unchangeable.
#
# In code, you recognize them because they use parentheses () instead of square brackets [].
#
# coordinates = (40.18, 44.51)  This stores two floating-point numbers together as a single unit (likely Latitude and Longitude).
#
# * Core Properties
#   - Ordered: The items stay in the exact sequence you put them in.
#   - Indexed: You can grab specific items by their position (e.g., "Give me the first item in the tuple").
#   - Immutable: This is the big one. Once a tuple is created, you cannot change, add, or remove items. It is "carved in stone."

# %%
coordinates = (40.18, 44.51)
coordinates
# Out:
# (40.18, 44.51)

# %% [markdown]
# ## Set { }

# %% [markdown]
# Set is a collection data structure that behaves very differently from lists or tuples.
#
# Its main purpose is to handle unique data and perform mathematical logic.
# * Unlike a list, a set doesn't care about the sequence.
#   If you print a set, the items might come out in a different order than you typed them.
# * Because there is no fixed order, you cannot ask for "the first item" in a set.

# %%
customer_ids = {1, 2, 3, 3, 4}
customer_ids
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ### Key Properties (The "Rules")

# %% [markdown]
# * Unordered: There is no "first" or "last" item. Because of this, you can't use an index (like s1[0]) to grab a value.
# * Unique values only: If you try to add 2 to a set that already has a 2, nothing happens. It's self-cleaning.
# * Mutable container: Even though the items inside must be unchangeable (hashable), the set itself can grow or shrink as you add or remove elements.
# * Fast membership checking: This is the set's "killer feature." Because it uses hashing, checking if an item exists (x in set) is nearly instantaneous, regardless of whether the set has 10 items or 10 million.

# %% [markdown]
# ### Creating Sets

# %%
s1 = {1, 2, 3}   # creating
s1
# Out:
# {1, 2, 3}

# %%
s1 = {1, 2, 2, 3}   # creating + cleaning
s1
# Out:
# {1, 2, 3}

# %% [markdown]
# You are telling Python directly to create a set containing those specific numbers.
#
# It is slightly faster because Python sees the curly braces and knows exactly what to do immediately.

# %%
s2 = set([1, 2, 2, 3])  # create a set from a list by cleaning it
s2
# Out:
# {1, 2, 3}

# %% [markdown]
# You are calling the set() function. To do this, you first created a list ([1, 2, 2, 3]) and then asked Python to convert that list into a set. This is a two-step process.

# %% [markdown]
# * Use { } when you already know the data you want to put in the set. It’s cleaner and more "Pythonic."
# * Use set() when you have an existing collection (like a list or a tuple) that you want to transform into a set—usually to remove duplicates or to make membership testing faster.

# %% [markdown]
# ### Basic Operations

# %% [markdown]
# #### 1- Handling Elements (The "Editing" Tools)

# %% [markdown]
# Since sets are mutable, you can modify them after they are created using these specific commands:

# %%
s = {1, 2, 3}

# %%
s.add(4)        # Add element
s
# Out:
# {1, 2, 3, 4}

# %%
s.remove(2)     # Remove element (error if not found)
s
# Out:
# {1, 3, 4}

# %%
# This is the "safe" version of remove. 
# It tries to delete 10, but if 10 isn't there, it just stays quiet and does nothing instead of crashing.
s.discard(10)   # Safe remove (no error)
s
# Out:
# {1, 3, 4}

# %%
s.pop()         # Remove random element
s
# Out:
# {3, 4}

# %%
s.pop()         # Remove random element
s
# Out:
# {4}

# %% [markdown]
# #### 2-Membership Check (The "Question" Tools)

# %% [markdown]
# This is where sets shine. Using the in keyword, you can instantly check if a piece of data exists within the collection.

# %%
3 in s   # True/false test
# Out:
# False

# %%
4 in s # True/false test
# Out:
# True

# %% [markdown]
# ### Set Algebra

# %% [markdown]
# It allows you to compare two different groups of data (segments) and find out how they overlap or differ.

# %% [markdown]
# #### Intersection (&)

# %%
segment_a = {1, 2, 3}
segment_b = {3, 4, 5}

# %%
# Finds only the elements that appear in both sets.
segment_a.intersection(segment_b)
# or
segment_a & segment_b
# Out:
# {3}

# %% [markdown]
# #### Union (|)

# %%
# Combines both sets into one, keeping only unique elements.
segment_a.union(segment_b)
# or
segment_a | segment_b
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# #### Difference (-)

# %%
# elements in A but not in B
segment_a.difference(segment_b)
# or
segment_a - segment_b
# Out:
# {1, 2}

# %% [markdown]
# #### Symmetric Difference (^)

# %%
# It keeps everything except the ones they have in common.
segment_a.symmetric_difference(segment_b)
# or
segment_a ^ segment_b
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# #### Analytical Use Cases

# %% [markdown]
# ##### Removing Duplicates

# %%
# Converting the list to a set automatically "de-duplicates" the data.
transactions = [101, 102, 102, 103, 104]
unique_transactions = set(transactions)
unique_transactions
# Out:
# {101, 102, 103, 104}

# %% [markdown]
# ##### Customer Overlap Between Campaigns (Intersection)

# %%
campaign_a = {1, 2, 3, 4}
campaign_b = {3, 4, 5, 6}

overlap = campaign_a & campaign_b
overlap
# Out:
# {3, 4}

# %% [markdown]
# ##### Finding New Customers (Difference)

# %%
new_customers = campaign_b - campaign_a
new_customers
# Out:
# {5, 6}

# %% [markdown]
# ##### Data Validation / Integrity Checks

# %%
valid_ids = {1, 2, 3, 4, 5}
incoming_ids = {2, 3, 6}

invalid_ids = incoming_ids - valid_ids
invalid_ids
# Out:
# {6}

# %% [markdown]
# 6 is flagged as invalid because it doesn't exist in the master list.

# %% [markdown]
# #### Limitations

# %% [markdown]
# ##### No Indexing or Guaranteed Order

# %% [markdown]
# In a list, items are like people standing in a line (everyone has a number).
# In a set, items are like balls in a bag; you can check if a ball is in there, but there is no "first" ball.
# In a set You cannot write s[0] to get the first item.

# %% [markdown]
# ##### The "Hashable" Rule

# %% [markdown]
# Elements inside a set must be immutable (unchangeable).
# To keep membership checking lightning-fast, Python creates a unique "fingerprint" (a hash) for every item.
# If an item can change (like a list can), its fingerprint would change too, and the set would "lose" it.
#
# This will fail
# s = {[1, 2], [3, 4]}

# %%
# correct type
s = {(1, 2), (3, 4)}

# %% [markdown]
# #### When to Use Sets

# %% [markdown]
# * Order doesn't matter: You don't need a "first, second, third" sequence.
#
# * Uniqueness is mandatory: You want to automatically ban duplicates.
#
# * Speed is a priority: You need to check for an item's existence instantly.
#
# * Group Logic: You need to compare two groups (like finding people who are in Group A but not Group B).

# %% [markdown]
# ##### Sets as a "Mathematical Tool"

# %% [markdown]
# shifts the perspective from sets being just "boxes for data" to being "engines for logic."
# Because they are built on mathematical set theory, they enable:
#
# * Efficient Deduplication: Cleaning messy data with one command.
# * Group Comparisons: Using Intersection, Union, and Difference to segment audiences.

# %% [markdown]
# ##### Analytical Real-World Use

# %% [markdown]
# where you'll actually see this in a data career:
# * Customer Segments: "Show me users who bought a subscription AND a gift card."
# * Campaign Overlaps: Measuring how much your Facebook ads and Google ads hit the same people.
# * Data Validation: Checking if a list of new IDs contains any "bad" IDs that shouldn't be there.
#
# Think of sets as your go-to structure for “who is in / who is not in” problems.

# %% [markdown]
# ## Dictionary {}

# %% [markdown]
# Dictionary (or dict), is one of the most powerful and frequently used data structures in Python.
# If a list is a numbered sequence of items, a dictionary is a labeled collection of information.
# It works just like a real-world dictionary: you look up a Key (the word) to find its Value (the definition).

# %% [markdown]
# ### Structure: Keys and Values

# %% [markdown]
# A dictionary is made of Key-Value pairs.
#
# customer = {"name": "Anna", "revenue": 150, "city": "Yerevan"}
#  * "name", "revenue", and "city" are the Keys.
#  * "Anna", 150, and "Yerevan" are the Values.

# %%
customer = {
    "name": "Anna",
    "revenue": 150,
    "city": "Yerevan"
}

customer
# Out:
# {'name': 'Anna', 'revenue': 150, 'city': 'Yerevan'}

# %% [markdown]
# ### Core Properties

# %% [markdown]
# * Unique Keys: You can't have two keys with the same name (e.g., you can't have two "name" labels for one customer).
#
# * Flexible Values: As you can see, the values can be different types: a string ("Anna"), an integer (150), or even another dictionary!
#
# * Fast Lookup: Like a set, dictionaries are optimized so that finding a value by its key is nearly instantaneous, even with millions of entries.

# %% [markdown]
# ### How to Use a Dictionary

# %%
# Accessing Data
#Instead of using a number index like [0], you use the key name in square brackets:

customer["revenue"]
# Out:
# 150

# %%
# Adding data 
customer["segment"] = "Premium"
# Updating data
customer["revenue"] = 200
customer
# Out:
# {'name': 'Anna', 'revenue': 200, 'city': 'Yerevan', 'segment': 'Premium'}

# %%
# Removing Data
del customer["city"]
customer
# Out:
# {'name': 'Anna', 'revenue': 200, 'segment': 'Premium'}

# %% [markdown]
# ## From Dictionary to Structured Data

# %%
customers = [
    {"name": "Anna", "revenue": 150},
    {"name": "David", "revenue": 220},
    {"name": "Mariam", "revenue": 90}
]

customers
# Out:
# [{'name': 'Anna', 'revenue': 150},
#  {'name': 'David', 'revenue': 220},
#  {'name': 'Mariam', 'revenue': 90}]

# %% [markdown]
# ### The Anatomy of Structured Data
# Look closely at how the customers variable is built:
#
# * The Outer Layer (The List): Notice the square brackets [ ]. This is a List used to hold a sequence of multiple items.
#
# * The Inner Layer (The Dictionaries): Inside that list, each item is a Dictionary { }. Each dictionary represents one specific row or record (e.g., one person).

# %% [markdown]
# ### Converting Code to a Table
# * The Keys in the dictionaries ("name", "revenue") become the Column Headers.
# * The Values ("Anna", 150) become the Cells.
# * Each Dictionary in the list becomes a Row.

# %% [markdown]
# ### Why This Matters: The Path to Pandas
# Pandas is the most popular Python library for data analysis.
# When you import a CSV file or an Excel sheet into Python, the computer essentially sees it as a giant version of this "List of Dictionaries."

# %% [markdown]
# Key Advantages
# Scalability:
# You can easily add a new customer by just adding one more dictionary to the list: customers.append({"name": "Leo", "revenue": 300}).
#
# Searchability:
# You can use a for loop to go through the list and find only customers where revenue > 100.
#
# Organization:
# It keeps related data (like a name and their specific revenue) tied together so they don't get mixed up with other people's data.

# %% [markdown]
# ## Transition to Pandas

# %% [markdown]
# ### Creating a DataFrame

# %% [markdown]
# DataFrame (df) is essentially a high-powered, programmatic version of an Excel spreadsheet.

# %%
import pandas as pd

data = {
    "name": ["Anna", "David", "Mariam"],
    "revenue": [150, 220, 90],
    "city": ["Yerevan", "Tbilisi", "Warsaw"]
}

df = pd.DataFrame(data)
df
# Out:
#      name  revenue     city
# 0    Anna      150  Yerevan
# 1   David      220  Tbilisi
# 2  Mariam       90   Warsaw

# %% [markdown]
# Index: The bold numbers on the far left ($0, 1, 2$). These are the row addresses.

# %% [markdown]
# ### Inspecting Structure (Health Check)

# %% [markdown]
# how to peek under the hood to see what your data actually looks like using three essential commands:

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     3 non-null      str
#  1   revenue  3 non-null      int64
#  2   city     3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes

# %% [markdown]
# df.info() show how many rows you have (3 entries).
#
# If any data is missing (3 non-null means every cell is filled).
#
# The Dtype (Data Type): You'll see str for text and int64 for whole numbers. This is where your knowledge of Integers and Strings becomes vital!

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# 3 rows and 3 columns.

# %%
df.columns
# Out:
# Index(['name', 'revenue', 'city'], dtype='str')

# %% [markdown]
# This lists out the names of your headers: ['name', 'revenue', 'city']
# and data type

# %% [markdown]
# ## Basic DataFrame Manipulation

# %% [markdown]
# Will help you how to "slice and dice" your data table and how to perform math across entire columns at once.

# %% [markdown]
# ### Selecting Columns

# %% [markdown]
# In a large dataset, you rarely need every single piece of information. Selecting columns allows you to focus on specific features:

# %% [markdown]
# Single Column: df["revenue"] extracts just the revenue data. This is often called a Series in Pandas.

# %%
df["revenue"]
# Out:
# 0    150
# 1    220
# 2     90
# Name: revenue, dtype: int64

# %% [markdown]
# Multiple Columns: df[["name", "revenue"]] extracts a subset of the table. Notice the double square brackets [[ ]].
#
# Tip: The inner brackets are a list of the column names you want, and the outer brackets tell the DataFrame to fetch them.

# %%
df[["name", "revenue"]]
# Out:
#      name  revenue
# 0    Anna      150
# 1   David      220
# 2  Mariam       90

# %% [markdown]
# ### Adding a Column (Feature Engineering)

# %%
t = 0.2
df["revenue_after_tax"] = df["revenue"] * (1 - t)
df
# Out:
#      name  revenue  revenue_after_tax segment
# 0    Anna      150              120.0    High
# 1   David      220              176.0    High
# 2  Mariam       90               72.0     Low

# %% [markdown]
# ### Removing a Column

# %%
df.drop("city", axis=1)
# Out:
#      name  revenue
# 0    Anna      150
# 1   David      220
# 2  Mariam       90

# %% [markdown]
# axis=1: This is crucial. In Pandas, axis=0 refers to rows, and axis=1 refers to columns.
#
# By saying axis=1, you are telling the computer, "Find the vertical column named 'city' and remove it."

# %%
df = df.drop("city", axis=1)

# %%
df
# Out:
#      name  revenue  revenue_after_tax
# 0    Anna      150              120.0
# 1   David      220              176.0
# 2  Mariam       90               72.0

# %% [markdown]
# df.drop("city", axis=1)  VS    df = df.drop("city", axis=1)
#
# When you just run df.drop("city", axis=1), Pandas shows you a preview of what the table looks like without that column.
#
# However, it doesn't actually change the original df variable.
#
# If you typed df again right after, the "city" column would still be there!
#
#
# To actually save your changes, you have to use Reassignment: df = df.drop("city", axis=1)
#
# This tells the computer: "Take the version of the table without the city column and save it over the old version of df."

# %% [markdown]
# ### Filtering Rows

# %%
df[df["revenue"] > 100]
# Out:
#     name  revenue  revenue_after_tax
# 0   Anna      150              120.0
# 1  David      220              176.0

# %% [markdown]
# df["revenue"] > 100
#
# Python revenue column and find in each raw if the value is greater than 100
#
# Then it creates a temporary list of True or False values
#
# df[df["revenue"] > 100]
#
# DataFrame then acts as a filter. It keeps every row that was marked True and hides every row that was False.

# %% [markdown]
# ### Updating Values (Conditional Logic) .loc

# %%
df.loc[df["revenue"] < 100, "segment"] = "Low"
df.loc[df["revenue"] >= 100, "segment"] = "High"
df
# Out:
#      name  revenue  revenue_after_tax segment
# 0    Anna      150              120.0    High
# 1   David      220              176.0    High
# 2  Mariam       90               72.0     Low

# %% [markdown]
# ### Analytical Flow

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Mutable Objects

# %% [markdown]
# Mutable objects can be changed after creation.
#
# You can reach into the "box" and swap out its contents without throwing the box away and getting a new one.
#
# Common Mutable Types:
# * List: You can change an item in a list (as shown in the example).
# * Dict (Dictionary): You can update a value for a specific key.
# * Set: You can add or remove unique elements.
# * Pandas DataFrame: You can change cell values, add columns, or drop rows.

# %%
sales = [100, 200, 150]
sales[0] = 300  # "The original object is modified." You didn't create a second list; you just edited the first one.
sales
# Out:
# [300, 200, 150]

# %% [markdown]
# ### Immutable Objects

# %% [markdown]
# Immutable types are designed for stability. Once you define them, their value is set in stone.
#
# Common Immutable Types:
# * int / float: Basic numbers.
# * str: Text strings.
# * bool: True/False values.
# * tuple: An ordered collection that is locked (unlike a List).

# %%
x = 10
x = x + 5
x
# Out:
# 15

# %% [markdown]
# * Python creates an integer object 10.
# * When you add 5, Python does not edit the 10. Instead, it calculates 15, creates a new integer object for it, and points the name x to that new object.
# * The original 10 is left behind and eventually deleted by the computer.

# %%
coordinates = (40.18, 44.510)
# coordinates[0] = 41   # Error

# %% [markdown]
# Immutable objects (like Tuples or Strings) are safer because you know they will never change behind your back.
#
# If you want to change an immutable object, you are forced to create a fresh copy, which keeps your original data "clean."

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Conditional Statements
# Conditional statements allow a program to make decisions. In data analytics, decisions appear everywhere:
#
# * Filtering rows
# * Classifying customers
# * Detecting anomalies
# * Creating segments
# * Handling missing values
#
# At the core of these operations lies the if statement.

# %% [markdown]
# ### The Basic if Statement

# %%
revenue = 150
if revenue > 100:
    print("High revenue")
else:
    print("Normal revenue")
# Out:
# High revenue

# %%
revenue = 150
if revenue > 100:
    print("High revenue")   # This belongs to the if statement

print("Analysis complete")  # This DOES NOT belong to the if statement
# Out:
# High revenue
# Analysis complete

# %% [markdown]
# Only the indented line is "protected" by the if.
#
#  If revenue is $150$, you see both messages.
#
#  If revenue was $50$, you would only see "Analysis complete." This is how you write code that performs a check and then moves on to the next task.

# %%
revenue = 150
if revenue > 100:
print("High revenue")   # IndentationError  # This line is NOT indented

# %% [markdown]
# * Python sees the colon (:) and expects the next line to be pushed to the right (indented).
#
# Because print starts at the very beginning of the line, Python gets "confused."

# %% [markdown]
# An if statement acts like a fork in the road. In the example:
#
# * Condition: revenue > 100 (Is 150 greater than 100? True)
#
# * The "If" Block: Because it's True, Python runs the indented line: print("High revenue").
#
# * The "Else" Block: This is the fallback. If the revenue had been 50, it would have skipped the first part and printed "Normal revenue".

# %% [markdown]
# Best Practices
#
# The image gives you a "style guide" to avoid bugs:
#
# * 4 Spaces: This is the industry standard.
#
# * No Mixing: Never use the "Tab" key and the "Space" key in the same file. It looks the same to your eyes, but it looks like a mess to the computer.
#
# * Consistency: Pick a style and stick to it.

# %% [markdown]
# ### Using elif for Multiple Conditions

# %%
revenue = 180

if revenue > 200:
    print("Very high revenue")
elif revenue > 100:
    print("High revenue")
elif revenue > 50:
    print("Medium revenue")
else:
    print("Low revenue")
# Out:
# High revenue

# %% [markdown]
# Important principles:
#
# * Conditions are evaluated from top to bottom
# * The first True condition executes
# * Remaining conditions are skipped

# %% [markdown]
# ### Boolean Expressions and Comparison Operators

# %% [markdown]
# Every conditional statement depends on a Boolean expression.
#
# A Boolean expression evaluates to either True or False.

# %%
100 > 50
100 == 50
100 != 50
# Out:
# True

# %% [markdown]
# Common comparison operators:
#
# * > greater than
# * < less than
# * >= greater than or equal
# * <= less than or equal
# * == equal
# * != not equal

# %% [markdown]
# ### Combining Conditions with Logical Operators

# %% [markdown]
# Often, a single condition is not enough.
#
# Python provides logical operators:
#
# * and
# * or
# * not

# %%
revenue = 150
is_active = True
if revenue >100 and is_active:
    print("Target customer")
# Out:
# Target customer

# %%
is_active = False

if not is_active:
    print("Customer is inactive")
# Out:
# Customer is inactive

# %%
revenue = 150
is_active = False
if revenue >100 and not is_active:
    print("Customer is inactive")
# Out:
# Customer is inactive

# %% [markdown]
# Rules:
#
# * and → both conditions must be True
# * or → at least one condition must be True
# * not → reverses the Boolean value

# %% [markdown]
# ### Nested Conditional Statements

# %%
revenue = 150
region = "EU"
if revenue > 100:
    if region == "EU":
        print("High EU revenue")
    else:
        print("High non-EU revenue")
# Out:
# High EU revenue
